# %%
from tqdm import tqdm
import numpy as np
from io import StringIO

# %%
import openai

with open("secret/secret_key_file.txt", 'r') as file:
    api_key = file.read().strip()

client = openai.OpenAI(api_key = api_key)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
from bs4 import BeautifulSoup

# Without error capture to ensure the output (whether success or failure) is reported back.
# Attempt to read tables from the HTML file using pandas
file_path = "data/Program - MSR 2022.html"

# %%
with open(file_path, 'r') as file:
    html_content = file.read()

# %%
soup = BeautifulSoup(html_content, 'lxml')

# %%
rows = soup.find_all('tr', class_='hidable')

# %%
# Regex to match date pattern (e.g., "Tue 16 May")
date_pattern = re.compile(r"\b(?:Mon|Tue|Wed|Thu|Fri|Sat|Sun)\s\d{1,2}\s(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)")

# %%
extracted_rows = []

# Loop through each row to extract required details
for row in rows:
    temp_row = []
    
    # Extract session details from parent div if not already extracted
    session_div = row.find_previous('div', class_='session-info-in-table')
    session = session_div.get_text(strip=True) if session_div else ''
    
    datetime_info = row.find('td', class_='text-right')
    talk_info = row.find_all('td')[-1]
    
    if datetime_info and talk_info:
        time = datetime_info.find('div', class_='start-time').get_text(strip=True) if datetime_info.find('div', class_='start-time') else ''
        duration = datetime_info.find('strong').get_text(strip=True) if datetime_info.find('strong') else ''
        
        # Calculate end time based on start time and duration if needed
        
        temp_row.append(time)
        # temp_row.append(end_time)  # Calculate and append end time if needed
        temp_row.append(duration)
        
        talk_title = talk_info.find('strong')
        if talk_title:
            temp_row.append(talk_title.get_text(strip=True))
            
            link = talk_title.find('a', href=True)
            temp_row.append(link['href'] if link else '')
        else:
            temp_row.extend(['', ''])
            
        # Extract authors
        authors_div = talk_info.find('div', class_='performers')
        authors = [author.get_text(strip=True) for author in authors_div.find_all('a')] if authors_div else []
        temp_row.append(authors)
        
        # Append session information
        temp_row.append(session)
        
        # Locate date information
        # Tip: You may need to adjust how you locate the 'date information' based on your HTML structure
        date_info = row.find_previous('div', class_='day-wrapper')
        if date_info:
            date_text = date_info.get_text(strip=True)
            matched_date = date_pattern.search(date_text)
            date = matched_date.group(0) if matched_date else "Date Not Found"
        else:
            date = None
        temp_row.append(date)
        
        extracted_rows.append(temp_row)

columns = ['Time', 'Duration', 'Talk Title', 'Link', 'Authors', 'Session', 'Date']
df = pd.DataFrame(extracted_rows, columns=columns)

df.head()
# Out:
#     Time Duration                                         Talk Title Link  \
# 0  22:00       4m  An Empirical Evaluation of GitHub Copilot’s Co...    #
# 1  22:04       4m  Comments on Comments: Where Code Review and Do...    #
# 2  22:08       7m  Does This Apply to Me? An Empirical Study of T...    #
# 3  22:15       7m  Towards Reliable Agile Iterative Planning via ...    #
# 4  22:22       7m  BotHunter: An Approach to Detect Software Bots...    #
#
#                                              Authors  \
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...
#
#                                              Session        Date
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May

# %%
# Convert all column names to lowercase and replace spaces with hyphens
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# Put date first
df = df[['date'] + [col for col in df.columns if col != 'date']]

# Convert Time to start_time as datetime and calculate end_time
df['start_time'] = pd.to_datetime(df['date'] + ' ' + df['time'], format='%a %d %b %H:%M')
df['duration'] = df['duration'].str.extract('(\d+)').astype(int)  # Extract duration in minutes
df['end_time'] = df['start_time'] + pd.to_timedelta(df['duration'], unit='m')

# Delete the Link column
df = df.drop(['link', 'time'], axis=1)

# Move Authors column to the last position
df = df[[col for col in df.columns if col != 'authors'] + ['authors']]

df = df[['session', 'date', 'start_time', 'end_time', 'duration', 'talk_title','authors']]

# Display the final data frame
df.head()
# Out:
#                                              session        date  \
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
#
#            start_time            end_time  duration  \
# 0 1900-05-17 22:00:00 1900-05-17 22:04:00         4
# 1 1900-05-17 22:04:00 1900-05-17 22:08:00         4
# 2 1900-05-17 22:08:00 1900-05-17 22:15:00         7
# 3 1900-05-17 22:15:00 1900-05-17 22:22:00         7
# 4 1900-05-17 22:22:00 1900-05-17 22:29:00         7
#
#                                           talk_title  \
# 0  An Empirical Evaluation of GitHub Copilot’s Co...
# 1  Comments on Comments: Where Code Review and Do...
# 2  Does This Apply to Me? An Empirical Study of T...
# 3  Towards Reliable Agile Iterative Planning via ...
# 4  BotHunter: An Approach to Detect Software Bots...
#
#                                              authors
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...

# %%
df['start_time'] = pd.to_datetime(df['start_time']).astype(int) // 10**9 // 60
df['end_time'] = pd.to_datetime(df['end_time']).astype(int) // 10**9 // 60

df.head()
# Out:
#                                              session        date  start_time  \
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619320
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619316
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619312
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619305
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619298
#
#    end_time  duration                                         talk_title  \
# 0 -36619316         4  An Empirical Evaluation of GitHub Copilot’s Co...
# 1 -36619312         4  Comments on Comments: Where Code Review and Do...
# 2 -36619305         7  Does This Apply to Me? An Empirical Study of T...
# 3 -36619298         7  Towards Reliable Agile Iterative Planning via ...
# 4 -36619291         7  BotHunter: An Approach to Detect Software Bots...
#
#                                              authors
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...

# %%
df.shape
# Out:
# (187, 7)

# %%
sessions = df.groupby("session").size()
valid_sessions = sessions[sessions>3].index
df = df[df.session.isin(valid_sessions)]

# %%
delete_talk_title = "Discussions and Q&A"
df = df[df.talk_title!=delete_talk_title]

# %%
df = df[~df.session.str.startswith("Blended")]

# %%
df.shape
# Out:
# (125, 7)

# %%
df.dtypes
# Out:
# session       object
# date          object
# start_time     int64
# end_time       int64
# duration       int64
# talk_title    object
# authors       object
# dtype: object

# %%
def merge_intervals(intervals):
    if not intervals:
        return 0
    
    # Sort intervals by the start time
    intervals.sort(key=lambda x: x[0])
    
    merged = [intervals[0]]
    for current_start, current_end in intervals[1:]:
        last_end = merged[-1][1]
        
        if current_start <= last_end:
            # There's an overlap, extend the previous interval
            merged[-1] = (merged[-1][0], max(last_end, current_end))
        else:
            # No overlap, add this interval as is
            merged.append((current_start, current_end))
    
    # Compute total duration in minutes (or another unit as desired)
    total_duration_minutes = sum((end - start) for start, end in merged)   # convert seconds to minutes
    return total_duration_minutes

total_durations = []

for date, group in df.groupby('date'):
    intervals = list(zip(group['start_time'], group['end_time']))
    total_duration = merge_intervals(intervals)
    total_durations.append({'date': date, 'total_duration': total_duration})

# Converting the result into a DataFrame
total_duration_df = pd.DataFrame(total_durations)

total_duration_df
# Out:
#          date  total_duration
# 0  Fri 20 May             147
# 1  Thu 19 May             314
# 2  Tue 17 May              36
# 3  Wed 18 May             238

# %%
dates = df.groupby("date")["duration"].sum().reset_index()


dates
# Out:
#          date  duration
# 0  Fri 20 May       147
# 1  Thu 19 May       314
# 2  Tue 17 May        36
# 3  Wed 18 May       238

# %% [markdown]
# ## Get Schedule through GPT

# %%
NUM_SESSION_LIST = [2,3,5,10,len(df.session.unique())] # number of sessions we will consider
SESSION_SIZE_LIST = [2, 5, 10] # number of papers in each session. 10 = "All papers".

# %%
N_ITERATIONS = 10 # we want to get confidence intervals

# %%
prompt_template = """
Program creation is the process of taking all the accepted papers to a conference and allocating a presentation slot for each paper with parallel sessions. 
The PC chairs of a conference typically do this manually. 
Assign sessions to the following papers based on the following constraints:
1. The total length of all paper presentations within a session should be less than or equal to the length of the session they are in. 
2. No new sessions should be added. 
3. The "Discussions and Q&A" event should only be at the end of a session if present. 
4. All papers must be assigned to some session. 

The output should contain the schedule in the form of the csv representation of a data frame. This csv representation should be in three quotes (```) on both sides so that I can easily extract it from your result and make a data frame. 
Example output format(use as many rows as the actual number of papers):

```
session@talk_title@duration
231@An Empirical Study on Maintainable Method Size in Java@7
223@Improve Quality of Cloud Serverless Architectures through Software Repository Mining@7
15@Extracting corrective actions from code repositories@7
15@How to Improve Deep Learning for Software Analytics (a case study with code smell detection)@7
11@ReCover: a Curated Dataset for Regression Testing Research@4
```

The list of paper and session titles are below: 

Session Lengths:
{sessions_df_string}

Paper durations:
{papers_df_string}


Make sure, above all else, that your response is formatted as requested, with the proper headers.

"""

# Print the start_prompt to verify
print(prompt_template[:500])
# Out:
# Program creation is the process of taking all the accepted papers to a conference and allocating a presentation slot for each paper with parallel sessions.
# The PC chairs of a conference typically do this manually.
# Assign sessions to the following papers based on the following constraints:
# 1. The total length of all paper presentations within a session should be less than or equal to the length of the session they are in.
# 2. No new sessions should be added.
# 3. The "Discussions and Q&A" event

# %%
def evaluate_schedule(df_human, df_llm):
    sessions_human = df_human.groupby("session")["duration"].sum().sort_values(ascending=False)
    sessions_llm = df_llm.groupby("session")["duration"].sum().sort_values(ascending=False)
    
    result = {}
    
    result["constraint_num_papers_error"] = len(df_llm) - len(df_human) 
    result["constraint_num_sessions_error"] = len(sessions_llm) - len(sessions_human)
    
    # Iterate and compare values
    for idx, session_duration_llm in sessions_llm.items():
        if idx-1 < len(sessions_human):
            session_duration_human = sessions_human.iloc[idx-1]
            result[f"constraint_error_session_{idx}_duration"] = session_duration_llm - session_duration_human 
            result[f"constraint_error_session_{idx}_duration_reasonable"] = session_duration_llm / session_duration_human - 1 <= 0.1
        else:
            result[f"constraint_error_session_{idx}_duration"] = np.inf
            result[f"constraint_error_session_{idx}_duration_reasonable"] = False

    
    return result

# %%
def get_llm_schedule(df):
    sessions = df.groupby("session")["duration"].sum()
    sessions_sorted = sessions.sort_values(ascending=False)

    prompt = prompt_template.format(
        sessions_df_string = sessions.to_string(index=False)
        ,papers_df_string = df[["talk_title","duration"]].to_string(index=False)
    )

    response = client.chat.completions.create(
    model= "gpt-4-0125-preview", #"gpt-3.5-turbo-0125",  # You can switch this to "gpt-4-turbo-preview", "gpt-3.5-turbo-0125"
        messages=[
            {
                "role": "user",
                "content": prompt
            },
        ],
        temperature=0.8,
        # max_tokens=256,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )
    ans_string = response.choices[0].message.content
    
    match = re.search("```\n(.*?)\n```", ans_string, re.DOTALL)
    if match:
        csv_string = match.group(1)  # Extract the actual CSV data
        # print("Extracted CSV:\n", csv_string)

        # Convert the CSV string to a DataFrame
        # StringIO is used to convert the string to a file-like object
        df_results = pd.read_csv(StringIO(csv_string), sep="@")
        

        # print("Got the df!")
    else:
        print("No CSV data found in the string. Abort!")
        print(ans_string[:200])
        raise ValueError
        
    # print(df_results.head())
    try:
        evaluation = evaluate_schedule(df, df_results)
    except:
        print(df_results.head())
        raise ValueError 
        
    return df_results, evaluate_schedule(df, df_results)

# %%
all_results = {}
for num_sessions in tqdm(NUM_SESSION_LIST, desc='Num Sessions Progress'):
    for session_size in tqdm(SESSION_SIZE_LIST, desc='Session Size Progress', leave=False):
        sampled_sessions = np.random.choice(df['session'].unique(), size=num_sessions, replace=False)

        # Loop over these selected sessions and sample the required number of papers
        session_samples = []
        for session in sampled_sessions:
            papers = df[df['session'] == session]
            # If there are fewer papers than the required session_size, we take all available, repeating if necessary
            sampled_papers = papers.sample(n=len(papers)) if len(papers) < session_size else papers.sample(n=session_size)
            session_samples.append(sampled_papers)

        # Now we store the sampled data
        df_dataset = pd.concat(session_samples)

        for iteration in tqdm(range(N_ITERATIONS), desc='Iterations Progress', leave=False):
            try:
                all_results[(num_sessions, session_size, iteration)] = df_dataset, get_llm_schedule(df_dataset), 1
            except ValueError: # try once more
                try:
                    all_results[(num_sessions, session_size, iteration)] = df_dataset, get_llm_schedule(df_dataset), 1
                except ValueError: # Give up and report failure. 
                    all_results[(num_sessions, session_size,iteration)] = {}, 0
                    print(f"Give up this one, {(num_sessions, session_size, iteration)}")
# Out:
# Num Sessions Progress:   0%|          | 0/5 [00:00<?, ?it/s]
# Session Size Progress:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:03<00:27,  3.03s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:06<00:27,  3.41s/it]
#
# Iterations Progress:  30%|███       | 3/10 [00:09<00:22,  3.15s/it]
#
# Iterations Progress:  40%|████      | 4/10 [00:13<00:19,  3.30s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [00:16<00:16,  3.38s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [00:19<00:12,  3.18s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [00:23<00:10,  3.41s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [00:26<00:06,  3.28s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [00:29<00:03,  3.15s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [00:34<00:00,  3.69s/it]
#
#
# Session Size Progress:  33%|███▎      | 1/3 [00:34<01:08, 34.16s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:07<01:05,  7.25s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:14<00:57,  7.14s/it]
#
# Iterations Progress:  30%|███       | 3/10 [00:21<00:49,  7.02s/it]
#
# Iterations Progress:  40%|████      | 4/10 [00:27<00:41,  6.93s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [00:35<00:35,  7.15s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [00:43<00:29,  7.28s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [00:52<00:24,  8.10s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [00:59<00:15,  7.75s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [01:09<00:08,  8.25s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [01:17<00:00,  8.13s/it]
#
#
# Session Size Progress:  67%|██████▋   | 2/3 [01:51<00:59, 59.39s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:08<01:19,  8.81s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:18<01:14,  9.35s/it]
#
# Iterations Progress:  30%|███       | 3/10 [00:28<01:08,  9.75s/it]
#
# Iterations Progress:  40%|████      | 4/10 [00:39<01:00, 10.16s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [00:50<00:53, 10.61s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [00:59<00:40, 10.03s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [01:11<00:32, 10.67s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [01:21<00:20, 10.21s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [01:30<00:09,  9.91s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [01:40<00:00,  9.90s/it]
#
#
# Session Size Progress: 100%|██████████| 3/3 [03:31<00:00, 78.04s/it]
# Num Sessions Progress:  20%|██        | 1/5 [03:31<14:05, 211.45s/it][A
# Session Size Progress:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:05<00:51,  5.77s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:09<00:38,  4.85s/it]
#
# Iterations Progress:  30%|███       | 3/10 [00:18<00:44,  6.42s/it]
#
# Iterations Progress:  40%|████      | 4/10 [00:22<00:32,  5.44s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [00:26<00:25,  5.12s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [00:32<00:21,  5.32s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [00:35<00:14,  4.73s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [00:41<00:09,  4.84s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [00:45<00:04,  4.75s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [00:49<00:00,  4.42s/it]
#
#
# Session Size Progress:  33%|███▎      | 1/3 [00:49<01:38, 49.31s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:10<01:37, 10.83s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:22<01:32, 11.60s/it]
#
# Iterations Progress:  30%|███       | 3/10 [00:31<01:11, 10.15s/it]
#
# Iterations Progress:  40%|████      | 4/10 [00:40<00:59,  9.86s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [00:50<00:49,  9.88s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [01:04<00:44, 11.05s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [01:14<00:32, 10.72s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [01:24<00:21, 10.52s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [01:35<00:10, 10.84s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [01:46<00:00, 10.90s/it]
#
#
# Session Size Progress:  67%|██████▋   | 2/3 [02:36<01:23, 83.10s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:13<02:01, 13.51s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:29<01:57, 14.71s/it]
#
# Iterations Progress:  30%|███       | 3/10 [00:45<01:48, 15.51s/it]
#
# Iterations Progress:  40%|████      | 4/10 [01:09<01:53, 18.87s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [01:23<01:25, 17.00s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [01:42<01:10, 17.67s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [01:58<00:52, 17.36s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [02:14<00:33, 16.76s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [02:28<00:15, 15.95s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [02:44<00:00, 15.87s/it]
#
#
# Session Size Progress: 100%|██████████| 3/3 [05:20<00:00, 120.16s/it]
# Num Sessions Progress:  40%|████      | 2/5 [08:51<13:46, 275.50s/it]
# Session Size Progress:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:08<01:17,  8.61s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:15<01:02,  7.82s/it]
#
# Iterations Progress:  30%|███       | 3/10 [00:24<00:57,  8.19s/it]
#
# Iterations Progress:  40%|████      | 4/10 [00:32<00:48,  8.06s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [00:39<00:38,  7.71s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [00:46<00:29,  7.47s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [00:55<00:23,  7.94s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [01:03<00:15,  7.90s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [01:10<00:07,  7.58s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [01:17<00:00,  7.69s/it]
#
#
# Session Size Progress:  33%|███▎      | 1/3 [01:17<02:35, 77.99s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:16<02:27, 16.34s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:39<02:41, 20.23s/it]
#
# Iterations Progress:  30%|███       | 3/10 [00:53<02:02, 17.55s/it]
#
# Iterations Progress:  40%|████      | 4/10 [01:08<01:38, 16.47s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [01:22<01:18, 15.73s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [01:40<01:05, 16.40s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [01:56<00:49, 16.34s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [02:13<00:32, 16.42s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [02:28<00:15, 15.88s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [02:43<00:00, 15.64s/it]
#
#
# Session Size Progress:  67%|██████▋   | 2/3 [04:01<02:08, 128.12s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:21<03:11, 21.27s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:42<02:50, 21.36s/it]
#
# Iterations Progress:  30%|███       | 3/10 [01:05<02:34, 22.03s/it]
#
# Iterations Progress:  40%|████      | 4/10 [01:40<02:43, 27.33s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [02:01<02:04, 24.94s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [02:22<01:33, 23.40s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [02:50<01:15, 25.08s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [03:13<00:48, 24.26s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [03:33<00:23, 23.11s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [03:59<00:00, 23.91s/it]
#
#
# Session Size Progress: 100%|██████████| 3/3 [08:00<00:00, 178.93s/it]
# Num Sessions Progress:  60%|██████    | 3/5 [16:52<12:18, 369.16s/it]
# Session Size Progress:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:14<02:07, 14.21s/it]
#
# Iterations Progress:  20%|██        | 2/10 [00:24<01:37, 12.18s/it]
#
# Iterations Progress:  30%|███       | 3/10 [00:38<01:28, 12.71s/it]
#
# Iterations Progress:  40%|████      | 4/10 [00:53<01:21, 13.65s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [01:04<01:04, 12.82s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [01:18<00:51, 12.99s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [01:29<00:37, 12.51s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [01:43<00:26, 13.10s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [01:55<00:12, 12.55s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [02:05<00:00, 11.81s/it]
#
#
# Session Size Progress:  33%|███▎      | 1/3 [02:05<04:10, 125.46s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:26<04:00, 26.73s/it]
#
# Iterations Progress:  20%|██        | 2/10 [01:00<04:06, 30.79s/it]
#
# Iterations Progress:  30%|███       | 3/10 [01:33<03:41, 31.69s/it]
#
# Iterations Progress:  40%|████      | 4/10 [01:59<02:57, 29.64s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [02:27<02:24, 28.94s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [02:57<01:56, 29.21s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [03:27<01:28, 29.51s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [04:01<01:01, 30.90s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [04:32<00:30, 30.94s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [05:02<00:00, 30.63s/it]
#
#
# Session Size Progress:  67%|██████▋   | 2/3 [07:07<03:49, 229.33s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:37<05:38, 37.60s/it]
#
# Iterations Progress:  20%|██        | 2/10 [01:19<05:19, 39.89s/it]
#
# Iterations Progress:  30%|███       | 3/10 [02:06<05:04, 43.54s/it]
#
# Iterations Progress:  40%|████      | 4/10 [02:48<04:15, 42.66s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [03:28<03:28, 41.66s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [04:12<02:49, 42.45s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [04:49<02:02, 40.90s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [05:40<01:27, 43.93s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [06:43<00:50, 50.10s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [07:26<00:00, 47.65s/it]
#
#
# Session Size Progress: 100%|██████████| 3/3 [14:33<00:00, 328.32s/it]
# Num Sessions Progress:  80%|████████  | 4/5 [31:26<09:28, 568.32s/it]
# Session Size Progress:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [00:25<03:49, 25.55s/it]
#
# Iterations Progress:  20%|██        | 2/10 [01:04<04:28, 33.57s/it]
#
# Iterations Progress:  30%|███       | 3/10 [01:53<04:43, 40.44s/it]
#
# Iterations Progress:  40%|████      | 4/10 [02:23<03:37, 36.21s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [02:52<02:49, 33.86s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [03:21<02:08, 32.21s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [03:50<01:33, 31.11s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [04:14<00:57, 28.69s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [04:41<00:28, 28.19s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [05:11<00:00, 28.73s/it]
#
#
# Session Size Progress:  33%|███▎      | 1/3 [05:11<10:22, 311.18s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [01:23<12:30, 83.44s/it]
#
# Iterations Progress:  20%|██        | 2/10 [02:49<11:20, 85.04s/it]
#
# Iterations Progress:  30%|███       | 3/10 [04:13<09:52, 84.64s/it]
#
# Iterations Progress:  40%|████      | 4/10 [05:35<08:21, 83.65s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [06:41<06:25, 77.15s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [08:18<05:35, 83.81s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [09:27<03:57, 79.05s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [10:31<02:28, 74.32s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [11:30<01:09, 69.46s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [12:47<00:00, 71.78s/it]
#
#
# Session Size Progress:  67%|██████▋   | 2/3 [17:58<09:39, 579.58s/it]
#
# Iterations Progress:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Iterations Progress:  10%|█         | 1/10 [01:28<13:16, 88.47s/it]
#
# Iterations Progress:  20%|██        | 2/10 [03:09<12:45, 95.63s/it]
#
# Iterations Progress:  30%|███       | 3/10 [04:34<10:35, 90.78s/it]
#
# Iterations Progress:  40%|████      | 4/10 [06:10<09:17, 92.85s/it]
#
# Iterations Progress:  50%|█████     | 5/10 [07:56<08:08, 97.64s/it]
#
# Iterations Progress:  60%|██████    | 6/10 [09:42<06:42, 100.66s/it]
#
# Iterations Progress:  70%|███████   | 7/10 [11:26<05:04, 101.56s/it]
#
# Iterations Progress:  80%|████████  | 8/10 [12:36<03:02, 91.49s/it]
#
# Iterations Progress:  90%|█████████ | 9/10 [13:59<01:29, 89.06s/it]
#
# Iterations Progress: 100%|██████████| 10/10 [15:33<00:00, 90.46s/it]
#
#
# Session Size Progress: 100%|██████████| 3/3 [33:32<00:00, 741.18s/it]
# Num Sessions Progress: 100%|██████████| 5/5 [1:04:58<00:00, 779.63s/it]

# %%
# Create a DataFrame to hold the information for EDA
data = {
    "num_sessions": [],
    "session_size": [],
    "iteration": [],
    "status": [],
    "constraint_num_papers_error": [],
    "constraint_num_sessions_error": []
}

# Iterate over all_results to populate the DataFrame
for k, v in all_results.items():
    num_sessions, session_size, iteration = k
    result, status = v
    data["num_sessions"].append(num_sessions)
    data["session_size"].append(session_size)
    data["iteration"].append(iteration)
    data["status"].append(status)
    
    if status == 1:  # Only if the result is valid
        data["constraint_num_papers_error"].append(result[1]['constraint_num_papers_error'])
        data["constraint_num_sessions_error"].append(result[1]['constraint_num_sessions_error'])
    else:
        data["constraint_num_papers_error"].append(None)
        data["constraint_num_sessions_error"].append(None)

results_df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 14
#      12 for k, v in all_results.items():
#      13     num_sessions, session_size, iteration = k
# ---> 14     result, status = v
#      15     data["num_sessions"].append(num_sessions)
#      16     data["session_size"].append(session_size)
#
# ValueError: too many values to unpack (expected 2)

# %%
results_df.head()

# %%
results_df.describe()

# %%
status_counts = results_df['status'].value_counts()
status_counts

# %%
# Visualize the status counts
plt.bar(status_counts.index.astype(str), status_counts.values)
plt.ylabel('Count')
plt.title('Distribution of Status Codes')
plt.show()

# %%
success_df = results_df[results_df['status'] == 1]

# Histogram of paper errors
plt.hist(success_df['constraint_num_papers_error'], bins=20, alpha=0.7, label='Num Papers Error')
plt.xlabel('Error Value')
plt.ylabel('Frequency')
plt.title('Histogram of Number of Papers Error')
plt.show()

# Histogram of sessions errors
plt.hist(success_df['constraint_num_sessions_error'], bins=20, alpha=0.7, color='red', label='Num Sessions Error')
plt.xlabel('Error Value')
plt.ylabel('Frequency')
plt.title('Histogram of Number of Sessions Error')
plt.show()

# %%
# Plot for the number of papers error vs. number of sessions
plt.figure(figsize=(12, 6))
sns.lineplot(data=success_df, x='num_sessions', y='constraint_num_papers_error')#, estimator=np, errorbar='sd')
plt.title('Number of Papers Error vs Number of Sessions with Confidence Interval')
plt.xlabel('Number of Sessions')
plt.ylabel('Mean Number of Papers Error')
plt.grid(True)
plt.show()

# %%
import string
import numpy as np

["".join(list(x)) for x in np.random.choice(list(string.ascii_lowercase),  size=(10,4))]
# Out:
# ['qnpf', 'iesv', 'jyee']

# %%
import pandas as pd
from pandas import testing
from sklearn.metrics import homogeneity_score, completeness_score
import random
import string


scores = []

def generate_random_string(length=8):
    """Generates a random string of fixed length"""
    letters = string.ascii_letters 
    random_string = ''.join(random.choice(letters) for i in range(length))
    return random_string

def fill_nan_with_random_string(df, length=8):
    """Fills NaN values in the DataFrame with a random alphanumeric string"""
    return df.apply(lambda x: generate_random_string(length) if pd.isna(x) else x)


for key, value in all_results.items():
    if value[1] != 0:  # check if the result from get_llm_schedule and not a failure
        df_ground_truth, df_predicted, evaluation = value
        df_predicted = df_predicted[0]
        
        df_merged = df_predicted.merge(df_ground_truth, how='outer', on="talk_title")
        df_merged["random_string_array_x"] = np.array(["".join(list(x)) for x in np.random.choice(list(string.ascii_lowercase),  size=(len(df_merged),10))])
        df_merged["random_string_array_y"] = ["".join(list(x)) for x in np.random.choice(list(string.ascii_lowercase),  size=(len(df_merged),10))]
        

        df_merged["session_x"] = df_merged["session_x"].fillna(df_merged["random_string_array_x"])
        df_merged["session_y"] = df_merged["session_y"].fillna(df_merged["random_string_array_y"])

        gt_sessions = df_merged['session_x'].astype(str)
        pred_sessions = df_merged['session_y'].astype(str)

        homogeneity = homogeneity_score(gt_sessions, pred_sessions)
        completeness = completeness_score(gt_sessions, pred_sessions)

        scores.append({"params": key,
                       "homogeneity": homogeneity,
                       "completeness": completeness})
    else:
        scores.append({"params": key,
                       "homogeneity": None,
                       "completeness": None})

# Now, let's use our function
score_df = pd.DataFrame(scores)
score_df.head()
# Out:
#       params  homogeneity  completeness
# 0  (2, 2, 0)          1.0           0.0
# 1  (2, 2, 1)          1.0           0.0
# 2  (2, 2, 2)          1.0           0.0
# 3  (2, 2, 3)          1.0           0.0
# 4  (2, 2, 4)          1.0           0.0

# %%
# Setting 'params' column as the index
score_df.set_index('params', inplace=True)

# Define a function to extract the last element of each tuple index
get_last_element = lambda x: x[:2]

# Grouping by the last element of the tuple index
grouped = score_df.groupby(get_last_element)  

# Compute mean and standard deviation for each group
mean_df = grouped.mean()
std_dev_df = grouped.std()

# %%
mean_df
# Out:
#           homogeneity  completeness
# (2, 2)       1.000000      0.000000
# (2, 5)       0.114569      0.011640
# (2, 10)      0.400591      0.393635
# (3, 2)       0.778704      0.755155
# (3, 5)       0.635202      0.633593
# (3, 10)      0.317881      0.307834
# (5, 2)       0.693910      0.450581
# (5, 5)       0.671476      0.582262
# (5, 10)      0.472881      0.486566
# (10, 2)      0.771156      0.477239
# (10, 5)      0.784744      0.772461
# (10, 10)     0.619857      0.566263
# (20, 2)      0.771205      0.650171
# (20, 5)      0.770838      0.799210
# (20, 10)     0.797187      0.806414

# %%
df_ground_truth
# Out:
#                                                session        date  \
# 104  Session 12: Integration & Large-Scale MiningTe...  Thu 19 May
# 103  Session 12: Integration & Large-Scale MiningTe...  Thu 19 May
# 102  Session 12: Integration & Large-Scale MiningTe...  Thu 19 May
# 105  Session 12: Integration & Large-Scale MiningTe...  Thu 19 May
# 101  Session 12: Integration & Large-Scale MiningTe...  Thu 19 May
# ..                                                 ...         ...
# 16   Session 3: Introspection, Vision, and Human As...  Wed 18 May
# 18   Session 3: Introspection, Vision, and Human As...  Wed 18 May
# 17   Session 3: Introspection, Vision, and Human As...  Wed 18 May
# 14   Session 3: Introspection, Vision, and Human As...  Wed 18 May
# 15   Session 3: Introspection, Vision, and Human As...  Wed 18 May
#
#      start_time  end_time  duration  \
# 104   -36616542 -36616535         7
# 103   -36616549 -36616542         7
# 102   -36616556 -36616549         7
# 105   -36616535 -36616528         7
# 101   -36616560 -36616556         4
# ..          ...       ...       ...
# 16    -36618889 -36618885         4
# 18    -36618878 -36618871         7
# 17    -36618885 -36618878         7
# 14    -36618900 -36618896         4
# 15    -36618896 -36618889         7
#
#                                             talk_title  \
# 104  Do Small Code Changes Merge Faster? A Multi-La...
# 103  Methods for Stabilizing Models across Large Sa...
# 102  Mining Code Review Data to Understand Waiting ...
# 105  FaST: A linear time stack trace alignment heur...
# 101  Is Open Source Eating the World’s Software? Me...
# ..                                                 ...
# 16    The General Index of Software Engineering Papers
# 18   Starting the InnerSource Journey: Key Goals an...
# 17   Challenges and Future Research Direction for M...
# 14   Geographic Diversity in Public Code Contributions
# 15   Operationalizing Threats to MSR Studies by Sim...
#
#                                                authors
# 104  [Gunnar Kudrjavets, Nachiappan Nagappan, Ayush...
# 103  [Suvodeep Majumder, Tianpei Xia, Rahul Krishna...
# 102  [Gunnar Kudrjavets, Aditya Kumar, Nachiappan N...
# 105  [Irving Muller Rodrigues, Daniel Aloise, Erald...
# 101  [Julius Musseau, John Speed Meyers, George P. ...
# ..                                                 ...
# 16            [Zeinab Abou Khalil, Stefano Zacchiroli]
# 18   [Daniel Izquierdo-Cortazar, Jesús Alonso-Gutié...
# 17   [Masanari Kondo, Shinobu Saito, IIMURA Yukako,...
# 14                  [Davide Rossi, Stefano Zacchiroli]
# 15                     [Johannes Härtel, Ralf Laemmel]
#
# [125 rows x 7 columns]

# %%
df_predicted
# Out:
#      session                                         talk_title  duration
# 0          1  Do Small Code Changes Merge Faster? A Multi-La...         7
# 1          1  Methods for Stabilizing Models across Large Sa...         7
# 2          1  Mining Code Review Data to Understand Waiting ...         7
# 3          1  FaST: A linear time stack trace alignment heur...         7
# 4          1                                         Discussion         2
# ..       ...                                                ...       ...
# 124       17  Operationalizing Threats to MSR Studies by Sim...         7
# 125       17                                         Discussion         2
# 126       18                                         Discussion        21
# 127       19                                         Discussion        21
# 128       20                                         Discussion        21
#
# [129 rows x 3 columns]

# %%
all_results_backup = all_results.copy()

# %%
for key, value in all_results.items():
    print(key)
    print(value[1][1])
    break
# Out:
# (2, 2, 0)
# {'constraint_num_papers_error': 0, 'constraint_num_sessions_error': -1, 'constraint_error_session_14_duration': inf, 'constraint_error_session_14_duration_reasonable': False}

# %%
import seaborn as sns

# Unpacking the tuple-index (which we assume is a multi-index right now)
score_df.reset_index(inplace=True)
score_df[['num_sessions', 'session_size', 'iteration']] = pd.DataFrame(score_df['params'].tolist(), index=score_df.index)

# Drop the 'params' as it now redundant
score_df.drop(columns="params", inplace=True)
score_df.head()
# Out:
#    homogeneity  completeness  num_sessions  session_size  iteration
# 0          1.0           0.0             2             2          0
# 1          1.0           0.0             2             2          1
# 2          1.0           0.0             2             2          2
# 3          1.0           0.0             2             2          3
# 4          1.0           0.0             2             2          4

# %%
plt.figure(figsize=(14, 7))

# Homogeneity scores by number of sessions
plt.subplot(1, 2, 1)
sns.boxplot(data=score_df, x='num_sessions', y='homogeneity')
plt.title('Homogeneity Scores by Number of Sessions')
plt.xlabel('Number of Sessions')
plt.ylabel('Homogeneity Score')

# Completeness scores by number of sessions
plt.subplot(1, 2, 2)
sns.boxplot(data=score_df, x='num_sessions', y='completeness')
plt.title('Completeness Scores by Number of Sessions')
plt.xlabel('Number of Sessions')
plt.ylabel('Completeness Score')
plt.savefig("images/corrected_homogeneity.png")

plt.tight_layout()
plt.show()

# Similarly for session size, plotting
plt.figure(figsize=(14, 7))

# Homogeneity scores by session size
plt.subplot(1, 2, 1)
sns.boxplot(data=score_df, x='session_size', y='homogeneity')
plt.title('Homogeneity Scores by Session Size')
plt.xlabel('Session Size')
plt.ylabel('Homogeneity Score')

# Completeness scores by session size
plt.subplot(1, 2, 2)
sns.boxplot(data=score_df, x='session_size', y='completeness')
plt.title('Completeness Scores by Session Size')
plt.xlabel('Session Size')
plt.ylabel('Completeness Score')

plt.savefig("images/corrected_completeness.png")

plt.tight_layout()
plt.show()

# %%
data = []
# Extracting data from the dictionary
for key, value in all_results.items():
    # Start with key elements
    row = list(key)
    # Append dictionary items (flatten the dictionary to row)
    row.extend(value[1][1].values())
    # Append row to data list
    data.append(row)

# Define the column names, starting with those for the tuple, followed by dictionary keys
# columns = ['num_sessions', 'session_size', 'iteration'] + list(all_results[next(iter(all_results.keys()))])

# Create DataFrame
df_error_rates = pd.DataFrame(data)#, columns=columns)
