# %%
from pulp import *
import numpy as np

# %%
import pandas as pd
import re
from bs4 import BeautifulSoup

# Without error capture to ensure the output (whether success or failure) is reported back.
# Attempt to read tables from the HTML file using pandas
file_path = "data/Program - MSR 2022.html"

# %%
with open(file_path, 'r') as file:
    html_content = file.read()

# %%
soup = BeautifulSoup(html_content, 'lxml')

# %%
rows = soup.find_all('tr', class_='hidable')

# %%
# Regex to match date pattern (e.g., "Tue 16 May")
date_pattern = re.compile(r"\b(?:Mon|Tue|Wed|Thu|Fri|Sat|Sun)\s\d{1,2}\s(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)")

# %%
extracted_rows = []

# Loop through each row to extract required details
for row in rows:
    temp_row = []
    
    # Extract session details from parent div if not already extracted
    session_div = row.find_previous('div', class_='session-info-in-table')
    session = session_div.get_text(strip=True) if session_div else ''
    
    datetime_info = row.find('td', class_='text-right')
    talk_info = row.find_all('td')[-1]
    
    if datetime_info and talk_info:
        time = datetime_info.find('div', class_='start-time').get_text(strip=True) if datetime_info.find('div', class_='start-time') else ''
        duration = datetime_info.find('strong').get_text(strip=True) if datetime_info.find('strong') else ''
        
        # Calculate end time based on start time and duration if needed
        
        temp_row.append(time)
        # temp_row.append(end_time)  # Calculate and append end time if needed
        temp_row.append(duration)
        
        talk_title = talk_info.find('strong')
        if talk_title:
            temp_row.append(talk_title.get_text(strip=True))
            
            link = talk_title.find('a', href=True)
            temp_row.append(link['href'] if link else '')
        else:
            temp_row.extend(['', ''])
            
        # Extract authors
        authors_div = talk_info.find('div', class_='performers')
        authors = [author.get_text(strip=True) for author in authors_div.find_all('a')] if authors_div else []
        temp_row.append(authors)
        
        # Append session information
        temp_row.append(session)
        
        # Locate date information
        # Tip: You may need to adjust how you locate the 'date information' based on your HTML structure
        date_info = row.find_previous('div', class_='day-wrapper')
        if date_info:
            date_text = date_info.get_text(strip=True)
            matched_date = date_pattern.search(date_text)
            date = matched_date.group(0) if matched_date else "Date Not Found"
        else:
            date = None
        temp_row.append(date)
        
        extracted_rows.append(temp_row)

columns = ['Time', 'Duration', 'Talk Title', 'Link', 'Authors', 'Session', 'Date']
df = pd.DataFrame(extracted_rows, columns=columns)

df.head()
# Out:
#     Time Duration                                         Talk Title Link  \
# 0  22:00       4m  An Empirical Evaluation of GitHub Copilot’s Co...    #
# 1  22:04       4m  Comments on Comments: Where Code Review and Do...    #
# 2  22:08       7m  Does This Apply to Me? An Empirical Study of T...    #
# 3  22:15       7m  Towards Reliable Agile Iterative Planning via ...    #
# 4  22:22       7m  BotHunter: An Approach to Detect Software Bots...    #
#
#                                              Authors  \
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...
#
#                                              Session        Date
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May

# %%
# Convert all column names to lowercase and replace spaces with hyphens
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# Put date first
df = df[['date'] + [col for col in df.columns if col != 'date']]

# Convert Time to start_time as datetime and calculate end_time
df['start_time'] = pd.to_datetime(df['date'] + ' ' + df['time'], format='%a %d %b %H:%M')
df['duration'] = df['duration'].str.extract('(\d+)').astype(int)  # Extract duration in minutes
df['end_time'] = df['start_time'] + pd.to_timedelta(df['duration'], unit='m')

# Delete the Link column
df = df.drop(['link', 'time'], axis=1)

# Move Authors column to the last position
df = df[[col for col in df.columns if col != 'authors'] + ['authors']]

df = df[['session', 'date', 'start_time', 'end_time', 'duration', 'talk_title','authors']]

# Display the final data frame
df.head()
# Out:
#                                              session        date  \
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
#
#            start_time            end_time  duration  \
# 0 1900-05-17 22:00:00 1900-05-17 22:04:00         4
# 1 1900-05-17 22:04:00 1900-05-17 22:08:00         4
# 2 1900-05-17 22:08:00 1900-05-17 22:15:00         7
# 3 1900-05-17 22:15:00 1900-05-17 22:22:00         7
# 4 1900-05-17 22:22:00 1900-05-17 22:29:00         7
#
#                                           talk_title  \
# 0  An Empirical Evaluation of GitHub Copilot’s Co...
# 1  Comments on Comments: Where Code Review and Do...
# 2  Does This Apply to Me? An Empirical Study of T...
# 3  Towards Reliable Agile Iterative Planning via ...
# 4  BotHunter: An Approach to Detect Software Bots...
#
#                                              authors
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...

# %%
df['start_time'] = pd.to_datetime(df['start_time']).astype(int) // 10**9 // 60
df['end_time'] = pd.to_datetime(df['end_time']).astype(int) // 10**9 // 60

df.head()
# Out:
#                                              session        date  start_time  \
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619320
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619316
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619312
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619305
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619298
#
#    end_time  duration                                         talk_title  \
# 0 -36619316         4  An Empirical Evaluation of GitHub Copilot’s Co...
# 1 -36619312         4  Comments on Comments: Where Code Review and Do...
# 2 -36619305         7  Does This Apply to Me? An Empirical Study of T...
# 3 -36619298         7  Towards Reliable Agile Iterative Planning via ...
# 4 -36619291         7  BotHunter: An Approach to Detect Software Bots...
#
#                                              authors
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...

# %%
df.dtypes
# Out:
# session       object
# date          object
# start_time     int64
# end_time       int64
# duration       int64
# talk_title    object
# authors       object
# dtype: object

# %%
len(df)
# Out:
# 187

# %%
df["session"].unique()[:3]
# Out:
# array(['Session 1Technical Papers/Registered ReportsatMSR Main room - even hoursChair(s):Hongyu ZhangUniversity of Newcastle,Masud RahmanDalhousie University',
#        'Session 2: Maintenance (Issues & Smells)Technical Papers/Registered Reports/Data and Tool Showcase Track/Industry TrackatMSR Main room - odd hoursChair(s):Alessio FerrariCNR-ISTI',
#        'Session 3: Introspection, Vision, and Human AspectsTechnical Papers/Data and Tool Showcase Track/Industry Track/Registered ReportsatMSR Main room - odd hoursChair(s):Alexander SerebrenikEindhoven University of Technology,Sebastian BaltesSAP SE & University of Adelaide'],
#       dtype=object)

# %%
df[df["session"]=='Session 1Technical Papers/Registered ReportsatMSR Main room - even hoursChair(s):Hongyu ZhangUniversity of Newcastle,Masud RahmanDalhousie University']
# Out:
#                                              session        date  start_time  \
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619320
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619316
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619312
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619305
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619298
# 5  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619291
# 6  Session 1Technical Papers/Registered Reportsat...  Tue 17 May   -36619284
#
#    end_time  duration                                         talk_title  \
# 0 -36619316         4  An Empirical Evaluation of GitHub Copilot’s Co...
# 1 -36619312         4  Comments on Comments: Where Code Review and Do...
# 2 -36619305         7  Does This Apply to Me? An Empirical Study of T...
# 3 -36619298         7  Towards Reliable Agile Iterative Planning via ...
# 4 -36619291         7  BotHunter: An Approach to Detect Software Bots...
# 5 -36619284         7  Recommending Code Improvements Based on Stack ...
# 6 -36619270        14                                Discussions and Q&A
#
#                                              authors
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...
# 5         [Chaiyong Ragkhitwetsagul, Matheus Paixao]
# 6                                                 []

# %%
def merge_intervals(intervals):
    if not intervals:
        return 0
    
    # Sort intervals by the start time
    intervals.sort(key=lambda x: x[0])
    
    merged = [intervals[0]]
    for current_start, current_end in intervals[1:]:
        last_end = merged[-1][1]
        
        if current_start <= last_end:
            # There's an overlap, extend the previous interval
            merged[-1] = (merged[-1][0], max(last_end, current_end))
        else:
            # No overlap, add this interval as is
            merged.append((current_start, current_end))
    
    # Compute total duration in minutes (or another unit as desired)
    total_duration_minutes = sum((end - start) for start, end in merged)   # convert seconds to minutes
    return total_duration_minutes

total_durations = []

for date, group in df.groupby('date'):
    intervals = list(zip(group['start_time'], group['end_time']))
    total_duration = merge_intervals(intervals)
    total_durations.append({'date': date, 'total_duration': total_duration})

# Converting the result into a DataFrame
total_duration_df = pd.DataFrame(total_durations)

total_duration_df
# Out:
#          date  total_duration
# 0  Fri 20 May             260
# 1  Mon 23 May             270
# 2  Thu 19 May             502
# 3  Tue 17 May              50
# 4  Tue 24 May             255
# 5  Wed 18 May             350

# %%
dates = df.groupby("date")["duration"].sum().reset_index()


dates
# Out:
#          date  duration
# 0  Fri 20 May       310
# 1  Mon 23 May       270
# 2  Thu 19 May       502
# 3  Tue 17 May        50
# 4  Tue 24 May       255
# 5  Wed 18 May       450

# %%
common_author_matrix = pd.DataFrame(np.zeros((len(df), len(df)), dtype=int), index=df['talk_title'], columns=df['talk_title'])

# Populate the matrix
for i in range(len(df)):
    for j in range(len(df)):
        # Intersect authors lists, if not empty set cell to 1
        if set(df.iloc[i]['authors']) & set(df.iloc[j]['authors']):
            common_author_matrix.iloc[i, j] = 1

common_author_matrix.head()
# Out:
# talk_title                                          An Empirical Evaluation of GitHub Copilot’s Code Suggestions  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  1
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  1
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Comments on Comments: Where Code Review and Documentation Meet  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  1
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Does This Apply to Me? An Empirical Study of Technical Context in Stack Overflow  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  1
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  1
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Towards Reliable Agile Iterative Planning via Predicting Documentation Changes of Work Items  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  1
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          BotHunter: An Approach to Detect Software Bots in GitHub  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  1
#
# talk_title                                          Recommending Code Improvements Based on Stack Overflow Answer Edits  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Discussions and Q&A  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                    0
# Comments on Comments: Where Code Review and Doc...                    0
# Does This Apply to Me? An Empirical Study of Te...                    0
# Towards Reliable Agile Iterative Planning via P...                    0
# BotHunter: An Approach to Detect Software Bots ...                    0
#
# talk_title                                          An Alternative Issue Tracking Dataset of Public Jira Repositories  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Smelly Variables in Ansible Infrastructure Code: Detection, Prevalence, and Lifetime  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Beyond Duplicates: Towards Understanding and Predicting Link Types in Issue Tracking Systems  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          ...  \
# talk_title                                          ...
# An Empirical Evaluation of GitHub Copilot’s Cod...  ...
# Comments on Comments: Where Code Review and Doc...  ...
# Does This Apply to Me? An Empirical Study of Te...  ...
# Towards Reliable Agile Iterative Planning via P...  ...
# BotHunter: An Approach to Detect Software Bots ...  ...
#
# talk_title                                          The General Index of Software Engineering Papers  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                 0
# Comments on Comments: Where Code Review and Doc...                                                 0
# Does This Apply to Me? An Empirical Study of Te...                                                 0
# Towards Reliable Agile Iterative Planning via P...                                                 0
# BotHunter: An Approach to Detect Software Bots ...                                                 0
#
# talk_title                                          Investigating the Impact of Forgetting in Software Development  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Discussions and Q&A  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                    0
# Comments on Comments: Where Code Review and Doc...                    0
# Does This Apply to Me? An Empirical Study of Te...                    0
# Towards Reliable Agile Iterative Planning via P...                    0
# BotHunter: An Approach to Detect Software Bots ...                    0
#
# talk_title                                          Code Review Practices for Refactoring Changes: An Empirical Study on OpenStack  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Painting the Landscape of Automotive Software in GitHub  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          SLNET: A Redistributable Corpus of 3rd-party Simulink Models  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          SoCCMiner: A Source Code-Comments and Comment-Context Miner  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          An Exploratory Study on Refactoring Documentation in Issues Handling  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Between JIRA and GitHub: ASFBot and its Influence on Human Comments in Issue Trackers  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Discussions and Q&A
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                    0
# Comments on Comments: Where Code Review and Doc...                    0
# Does This Apply to Me? An Empirical Study of Te...                    0
# Towards Reliable Agile Iterative Planning via P...                    0
# BotHunter: An Approach to Detect Software Bots ...                    0
#
# [5 rows x 187 columns]

# %% [markdown]
# ## Perform linear programming

# %%
papers = df[["talk_title","authors","duration"]]
papers.head()
# Out:
#                                           talk_title  \
# 0  An Empirical Evaluation of GitHub Copilot’s Co...
# 1  Comments on Comments: Where Code Review and Do...
# 2  Does This Apply to Me? An Empirical Study of T...
# 3  Towards Reliable Agile Iterative Planning via ...
# 4  BotHunter: An Approach to Detect Software Bots...
#
#                                              authors  duration
# 0                          [Nhan Nguyen, Sarah Nadi]         4
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...         4
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...         7
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...         7
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...         7

# %%
df.dtypes
# Out:
# session       object
# date          object
# start_time     int64
# end_time       int64
# duration       int64
# talk_title    object
# authors       object
# dtype: object

# %%
sessions = df.groupby("session")["duration"].sum()

sessions.head()
# Out:
# session
# Blended Technical Session 1 (Integration, Large-scale mining, and Software Ecosystems)Technical Papers/Data and Tool Showcase TrackatRoom 315+316Chair(s):Bogdan VasilescuCarnegie Mellon University, USA              90
# Blended Technical Session 2 (Machine Learning and Information Retrieval)Technical Papers/Data and Tool Showcase TrackatRoom 315+316Chair(s):Preetha ChatterjeeDrexel University, USA                                   90
# Blended Technical Session 3 (Smells and Maintenance)Technical Papers/Mining Challenge/Registered Reports/Data and Tool Showcase TrackatRoom 315+316Chair(s):Andy ZaidmanDelft University of Technology                 90
# Blended Technical Session 4 (Introspection, Vision, and Human Aspects)Technical Papers/Registered Reports/Data and Tool Showcase TrackatRoom 315+316Chair(s):Ayushi RastogiUniversity of Groningen, The Netherlands    75
# Blended Technical Session 5 (Miscellaneous)Technical Papers/Data and Tool Showcase Track/Mining ChallengeatRoom 315+316Chair(s):Luís CruzDeflt University of Technology                                                90
# Name: duration, dtype: int64

# %%
df.groupby("session")["duration"].sum().values
# Out:
# array([90, 90, 90, 75, 90, 50, 50, 90, 50, 50, 50, 50, 50, 50, 50, 50, 60,
#        50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 51, 51])

# %%
df.groupby("session").size().values
# Out:
# array([8, 7, 7, 6, 7, 1, 7, 3, 1, 8, 8, 7, 7, 7, 7, 9, 8, 7, 7, 7, 7, 8,
#        8, 8, 8, 7, 1, 1, 1, 1, 4, 4])

# %%
len(sessions)
# Out:
# 32

# %%
# Assumption of variables for illustration
num_sessions = len(sessions)  # Number of sessions as defined by PC chairs
session_lengths = sessions.values  # Length of each session in minutes
num_tracks = 1 # FOR NOW, ASSUME WE ONLY HAVE A SINGLE TRACK

# %%
# Initiate the problem
prob = LpProblem("Conference_Schedule_Optimization", LpMinimize)

# Decision variables
schedule = LpVariable.dicts("schedule", 
                            ((i, j, k) 
                             for i in range(len(papers)) # paper number
                             for j in range(num_sessions) # session number
                             for k in range(num_tracks) # track number
                            ) 
                            ,cat='Binary' # to make it precise
                       )
# start_times = LpVariable.dicts("start_times", 
#                             (i 
#                              for i in range(len(papers)) # paper number
#                             ) # start time
#                             ,cat='Continuous'
#                        )
# end_times = LpVariable.dicts("end_times", 
#                             (i 
#                              for i in range(len(papers)) # paper number
#                             ) # end time
#                             ,cat='Continuous'
#                        )

# Objective function: For the basic structure, we make it a dummy one as our main focus is on satisfying constraints
prob += 0, "ArbitraryObjective"

# %%
# Constraints

# for i in range(len(papers)):
#     for j in range(num_sessions):
#         for k in range(num_tracks):
#             prob += schedule[(i, j, k)] >= 0
#             prob += schedule[(i, j, k)] <= 1


# Ensure each paper is scheduled exactly once
for i in range(len(papers)):
    prob += lpSum(schedule[(i, j, k)] for j in range(num_sessions) for k in range(num_tracks)) == 1, f"One_placement_paper_{i}"

# Do not exceed session length
for j in range(num_sessions):
    for k in range(num_tracks):
        prob += lpSum(schedule[(i, j, k)] * papers.loc[i]["duration"] for i in range(len(papers))) <= session_lengths[j], f"Session_length_limit_{j}_{k}"

        
# # No parallel scheduling of papers with common authors
# # We implement it by adding constraints to make sure that no papers with common authors are scheduled on parallel sessions. 
# for i1 in range(len(papers)):
#     for i2 in range(len(papers)):
#         if i1 != i2 and set(papers.loc[i1]["authors"]).intersection(papers.loc[i1]["authors"]):
#             for j in range(num_sessions):
#                 for k1 in range(num_tracks):
#                     for k2 in range(num_tracks):
#                         prob += schedule[(i1, j, k1)] + schedule[(i2, j, k2)] <= 1, f"No_parallel_{j1}_{j2}_session_{i}"

# %%
# Solve the problem
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /var/tmp/4c73a7df0b484a0fa438968e852b8778-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/tmp/4c73a7df0b484a0fa438968e852b8778-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 224 COLUMNS
# At line 24162 RHS
# At line 24382 BOUNDS
# At line 30368 ENDATA
# Problem MODEL has 219 rows, 5985 columns and 11968 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.05 seconds
# Cgl0005I 187 SOS with 5984 members
# Cgl0004I processed model has 219 rows, 5984 columns (5984 integer (5984 of which binary)) and 11968 elements
# Cbc0038I Initial state - 54 integers unsatisfied sum - 14.7971
# Cbc0038I Pass   1: suminf.    8.86048 (42) obj. 0 iterations 188
# Cbc0038I Pass   2: suminf.    8.54619 (42) obj. 0 iterations 8
# Cbc0038I Pass   3: suminf.    7.67667 (40) obj. 0 iterations 149
# Cbc0038I Pass   4: suminf.    6.63667 (39) obj. 0 iterations 65
# Cbc0038I Pass   5: suminf.    6.63667 (39) obj. 0 iterations 0
# Cbc0038I Pass   6: suminf.    7.25143 (36) obj. 0 iterations 130
# Cbc0038I Pass   7: suminf.    5.60714 (36) obj. 0 iterations 94
# Cbc0038I Pass   8: suminf.    5.60714 (36) obj. 0 iterations 3
# Cbc0038I Pass   9: suminf.    6.45714 (37) obj. 0 iterations 126
# Cbc0038I Pass  10: suminf.    6.04286 (35) obj. 0 iterations 84
# Cbc0038I Pass  11: suminf.    6.04286 (35) obj. 0 iterations 2
# Cbc0038I Pass  12: suminf.    6.35714 (37) obj. 0 iterations 67
# Cbc0038I Pass  13: suminf.    6.35714 (36) obj. 0 iterations 39
# Cbc0038I Pass  14: suminf.    6.04286 (36) obj. 0 iterations 55
# Cbc0038I Pass  15: suminf.   12.95860 (56) obj. 0 iterations 274
# Cbc0038I Pass  16: suminf.    7.24527 (42) obj. 0 iterations 236
# Cbc0038I Pass  17: suminf.    7.13098 (41) obj. 0 iterations 54
# Cbc0038I Pass  18: suminf.    8.57185 (41) obj. 0 iterations 236
# Cbc0038I Pass  19: suminf.    7.11661 (38) obj. 0 iterations 113
# Cbc0038I Pass  20: suminf.    6.99661 (38) obj. 0 iterations 28
# Cbc0038I Pass  21: suminf.    7.64042 (40) obj. 0 iterations 190
# Cbc0038I Pass  22: suminf.    7.09756 (40) obj. 0 iterations 102
# Cbc0038I Pass  23: suminf.    7.04042 (39) obj. 0 iterations 11
# Cbc0038I Pass  24: suminf.    6.59661 (38) obj. 0 iterations 172
# Cbc0038I Pass  25: suminf.    6.53947 (37) obj. 0 iterations 114
# Cbc0038I Pass  26: suminf.    6.43089 (38) obj. 0 iterations 115
# Cbc0038I Pass  27: suminf.    6.43089 (39) obj. 0 iterations 44
# Cbc0038I Pass  28: suminf.    6.53947 (37) obj. 0 iterations 103
# Cbc0038I Pass  29: suminf.   15.40959 (57) obj. 0 iterations 286
# Cbc0038I Pass  30: suminf.    7.08570 (43) obj. 0 iterations 255
# Cbc0038I Pass  31: suminf.    7.08570 (43) obj. 0 iterations 18
# Cbc0038I Pass  32: suminf.    8.03998 (42) obj. 0 iterations 227
# Cbc0038I Pass  33: suminf.    7.37903 (41) obj. 0 iterations 135
# Cbc0038I Pass  34: suminf.    7.37903 (41) obj. 0 iterations 17
# Cbc0038I Pass  35: suminf.    8.95046 (44) obj. 0 iterations 227
# Cbc0038I Pass  36: suminf.    8.19903 (42) obj. 0 iterations 141
# Cbc0038I Pass  37: suminf.    8.11903 (42) obj. 0 iterations 19
# Cbc0038I Pass  38: suminf.    8.07903 (41) obj. 0 iterations 40
# Cbc0038I Pass  39: suminf.    8.48760 (42) obj. 0 iterations 160
# Cbc0038I Pass  40: suminf.    7.72760 (42) obj. 0 iterations 116
# Cbc0038I Pass  41: suminf.    8.63903 (42) obj. 0 iterations 219
# Cbc0038I Pass  42: suminf.    8.51903 (43) obj. 0 iterations 170
# Cbc0038I Pass  43: suminf.    8.02760 (43) obj. 0 iterations 64
# Cbc0038I Pass  44: suminf.    7.90760 (42) obj. 0 iterations 44
# Cbc0038I Pass  45: suminf.    8.53903 (43) obj. 0 iterations 188
# Cbc0038I Pass  46: suminf.    8.45903 (43) obj. 0 iterations 90
# Cbc0038I Pass  47: suminf.    8.41903 (42) obj. 0 iterations 29
# Cbc0038I Pass  48: suminf.    8.54760 (42) obj. 0 iterations 181
# Cbc0038I Pass  49: suminf.    8.02760 (43) obj. 0 iterations 125
# Cbc0038I Pass  50: suminf.    7.90760 (42) obj. 0 iterations 14
# Cbc0038I Pass  51: suminf.    8.49903 (42) obj. 0 iterations 133
# Cbc0038I Pass  52: suminf.    8.01903 (42) obj. 0 iterations 111
# Cbc0038I Pass  53: suminf.    7.97903 (41) obj. 0 iterations 43
# Cbc0038I Pass  54: suminf.    8.50760 (43) obj. 0 iterations 159
# Cbc0038I Pass  55: suminf.    7.82760 (43) obj. 0 iterations 104
# Cbc0038I Pass  56: suminf.    8.53903 (42) obj. 0 iterations 145
# Cbc0038I Pass  57: suminf.    8.41903 (42) obj. 0 iterations 110
# Cbc0038I Pass  58: suminf.    7.97903 (41) obj. 0 iterations 13
# Cbc0038I Pass  59: suminf.    7.94760 (42) obj. 0 iterations 225
# Cbc0038I Pass  60: suminf.    7.90760 (42) obj. 0 iterations 165
# Cbc0038I Pass  61: suminf.    8.49903 (42) obj. 0 iterations 174
# Cbc0038I Pass  62: suminf.    7.93903 (42) obj. 0 iterations 99
# Cbc0038I Pass  63: suminf.    7.89903 (41) obj. 0 iterations 28
# Cbc0038I Pass  64: suminf.    7.90760 (43) obj. 0 iterations 219
# Cbc0038I Pass  65: suminf.    7.82760 (43) obj. 0 iterations 168
# Cbc0038I Pass  66: suminf.    8.53903 (42) obj. 0 iterations 145
# Cbc0038I Pass  67: suminf.    8.41903 (42) obj. 0 iterations 102
# Cbc0038I Pass  68: suminf.    7.97903 (41) obj. 0 iterations 11
# Cbc0038I Pass  69: suminf.    8.18760 (42) obj. 0 iterations 197
# Cbc0038I Pass  70: suminf.    7.90760 (42) obj. 0 iterations 138
# Cbc0038I Pass  71: suminf.    7.93903 (42) obj. 0 iterations 114
# Cbc0038I Pass  72: suminf.    7.89903 (41) obj. 0 iterations 82
# Cbc0038I Pass  73: suminf.    7.90760 (41) obj. 0 iterations 212
# Cbc0038I Pass  74: suminf.    7.82760 (43) obj. 0 iterations 171
# Cbc0038I Pass  75: suminf.    8.53903 (42) obj. 0 iterations 153
# Cbc0038I Pass  76: suminf.    8.41903 (42) obj. 0 iterations 116
# Cbc0038I Pass  77: suminf.    7.97903 (41) obj. 0 iterations 10
# Cbc0038I Pass  78: suminf.    7.94760 (42) obj. 0 iterations 209
# Cbc0038I Pass  79: suminf.    7.90760 (42) obj. 0 iterations 166
# Cbc0038I Pass  80: suminf.    8.53903 (43) obj. 0 iterations 184
# Cbc0038I Pass  81: suminf.    8.45903 (43) obj. 0 iterations 90
# Cbc0038I Pass  82: suminf.    8.41903 (42) obj. 0 iterations 27
# Cbc0038I Pass  83: suminf.    8.54760 (43) obj. 0 iterations 201
# Cbc0038I Pass  84: suminf.    8.02760 (43) obj. 0 iterations 159
# Cbc0038I Pass  85: suminf.    7.90760 (42) obj. 0 iterations 13
# Cbc0038I Pass  86: suminf.    7.95618 (42) obj. 0 iterations 71
# Cbc0038I Pass  87: suminf.    7.89903 (41) obj. 0 iterations 74
# Cbc0038I Pass  88: suminf.    8.02760 (41) obj. 0 iterations 170
# Cbc0038I Pass  89: suminf.   11.74169 (53) obj. 0 iterations 312
# Cbc0038I Pass  90: suminf.    8.11532 (43) obj. 0 iterations 258
# Cbc0038I Pass  91: suminf.    8.11532 (43) obj. 0 iterations 12
# Cbc0038I Pass  92: suminf.    8.01532 (42) obj. 0 iterations 28
# Cbc0038I Pass  93: suminf.    9.92452 (44) obj. 0 iterations 260
# Cbc0038I Pass  94: suminf.    7.67786 (41) obj. 0 iterations 183
# Cbc0038I Pass  95: suminf.    7.67786 (41) obj. 0 iterations 16
# Cbc0038I Pass  96: suminf.    8.79929 (40) obj. 0 iterations 203
# Cbc0038I Pass  97: suminf.    7.73429 (40) obj. 0 iterations 148
# Cbc0038I Pass  98: suminf.    7.73429 (39) obj. 0 iterations 46
# Cbc0038I Pass  99: suminf.    7.64857 (40) obj. 0 iterations 99
# Cbc0038I Pass 100: suminf.   15.49429 (58) obj. 0 iterations 287
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 5292 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 219 rows 5984 columns, reduced to 135 rows 594 columns
# Cbc0038I Mini branch and bound did not improve solution (0.79 seconds)
# Cbc0038I Full problem 220 rows 5984 columns, reduced to 220 rows 5984 columns - too large
# Cbc0038I After 1.60 seconds - Feasibility pump exiting - took 1.48 seconds
# Cbc0031I 159 added rows had average density of 149.68553
# Cbc0013I At root node, 159 cuts changed objective from 0 to 0 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 517 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.231 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 130 row cuts average 1973.0 elements, 0 column cuts (0 active)  in 0.381 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 12 row cuts average 17.5 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 42 row cuts average 290.0 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 98 row cuts average 159.2 elements, 0 column cuts (0 active)  in 0.041 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 69 row cuts average 190.1 elements, 0 column cuts (0 active)  in 0.060 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 0 (3.36 seconds)
# Cbc0010I After 100 nodes, 61 on tree, 1e+50 best solution, best possible 0 (6.71 seconds)
# Cbc0010I After 200 nodes, 115 on tree, 1e+50 best solution, best possible 0 (8.29 seconds)
# Cbc0010I After 300 nodes, 167 on tree, 1e+50 best solution, best possible 0 (9.44 seconds)
# Cbc0010I After 400 nodes, 218 on tree, 1e+50 best solution, best possible 0 (10.42 seconds)
# Cbc0010I After 500 nodes, 271 on tree, 1e+50 best solution, best possible 0 (11.34 seconds)
# Cbc0010I After 600 nodes, 320 on tree, 1e+50 best solution, best possible 0 (12.16 seconds)
# Cbc0010I After 700 nodes, 369 on tree, 1e+50 best solution, best possible 0 (13.03 seconds)
# Cbc0010I After 800 nodes, 417 on tree, 1e+50 best solution, best possible 0 (13.90 seconds)
# Cbc0010I After 900 nodes, 462 on tree, 1e+50 best solution, best possible 0 (14.77 seconds)
# Cbc0010I After 1000 nodes, 514 on tree, 1e+50 best solution, best possible 0 (15.62 seconds)
# Cbc0010I After 1100 nodes, 613 on tree, 1e+50 best solution, best possible 0 (16.31 seconds)
# Cbc0010I After 1200 nodes, 685 on tree, 1e+50 best solution, best possible 0 (16.92 seconds)
# Cbc0010I After 1300 nodes, 732 on tree, 1e+50 best solution, best possible 0 (17.40 seconds)
# Cbc0010I After 1400 nodes, 734 on tree, 1e+50 best solution, best possible 0 (17.87 seconds)
# Cbc0010I After 1500 nodes, 736 on tree, 1e+50 best solution, best possible 0 (18.31 seconds)
# Cbc0010I After 1600 nodes, 735 on tree, 1e+50 best solution, best possible 0 (18.73 seconds)
# Cbc0010I After 1700 nodes, 743 on tree, 1e+50 best solution, best possible 0 (19.20 seconds)
# Cbc0010I After 1800 nodes, 740 on tree, 1e+50 best solution, best possible 0 (19.69 seconds)
# Cbc0010I After 1900 nodes, 739 on tree, 1e+50 best solution, best possible 0 (20.17 seconds)
nodes, 1812 on tree, 1e+50 best solution, best possible 0 (2236.45 seconds)
# Cbc0010I After 739300 nodes, 1812 on tree, 1e+50 best solution, best possible 0 (2236.79 seconds)
# Cbc0010I After 739400 nodes, 1813 on tree, 1e+50 best solution, best possible 0 (2237.11 seconds)
# Cbc0010I After 739500 nodes, 1812 on tree, 1e+50 best solution, best possible 0 (2237.47 seconds)
# Cbc0010I After 739600 nodes, 1808 on tree, 1e+50 best solution, best possible 0 (2237.76 seconds)
# Cbc0010I After 739700 nodes, 1813 on tree, 1e+50 best solution, best possible 0 (2238.07 seconds)
# Cbc0010I After 739800 nodes, 1809 on tree, 1e+50 best solution, best possible 0 (2238.37 seconds)
# Cbc0010I After 739900 nodes, 1810 on tree, 1e+50 best solution, best possible 0 (2238.74 seconds)
# Cbc0010I After 740000 nodes, 1809 on tree, 1e+50 best solution, best possible 0 (2239.02 seconds)
# Cbc0010I After 740100 nodes, 1811 on tree, 1e+50 best solution, best possible 0 (2239.28 seconds)
# Cbc0010I After 740200 nodes, 1807 on tree, 1e+50 best solution, best possible 0 (2239.54 seconds)
# Cbc0027I Exiting on user event
# Cbc0005I Partial search - best objective 1e+50 (best possible 0), took 5511248 iterations and 740262 nodes (2239.84 seconds)
# Cbc0032I Strong branching done 5101118 times (16302143 iterations), fathomed 340220 nodes and fixed 246651 variables
# Cbc0035I Maximum depth 630, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 10 times and created 517 cuts of which 0 were active after adding rounds of cuts (0.231 seconds)
# Gomory was tried 10 times and created 130 cuts of which 0 were active after adding rounds of cuts (0.381 seconds)
# Knapsack was tried 10 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.015 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 10 times and created 42 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 10 times and created 98 cuts of which 0 were active after adding rounds of cuts (0.041 seconds)
# ZeroHalf was tried 10 times and created 69 cuts of which 0 were active after adding rounds of cuts (0.060 seconds)
# ImplicationCuts was tried 709 times and created 439 cuts of which 0 were active after adding rounds of cuts (0.146 seconds)
#
# Result - User ctrl-cuser ctrl-c
#
# No feasible solution found
# Lower bound:                    0.000
# Enumerated nodes:               740262
# Total iterations:               5511248
# Time (CPU seconds):             2239.44
# Time (Wallclock seconds):       2239.85
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2239.45   (Wallclock seconds):       2239.86
# KeyboardInterrupt

# %%
# Initialize an empty list to hold the results
results = []

# Iterate over each session and track
for j in range(num_sessions):
    for k in range(num_tracks):
        session_number = j + 1
        # Iterate over each paper
        for i in range(len(papers)):
            if schedule[(i, j, k)].varValue == 1:
                # Prepare a dict with the required information
                paper_info = {
                    'session': session_number,
                    'title': papers.loc[i]['talk_title'],
                    'duration': papers.loc[i]['duration'],
                    'validity': 1
                }
                # Append to the results list
                results.append(paper_info)
            elif schedule[(i, j, k)].varValue > 0:
                # Prepare a dict with the required information
                paper_info = {
                    'session': session_number,
                    'title': papers.loc[i]['talk_title'],
                    'duration': papers.loc[i]['duration'],
                    'validity': 0
                }
                # Append to the results list
                results.append(paper_info)

# Convert the list of dictionaries into a DataFrame
df_results = pd.DataFrame(results)

# If you need to see the first few rows of the DataFrame to ensure it's correct
df_results.head()

# %%
len(df_results), len(df)

# %%
df_results["validity"].mean()

# %%
new_session_lengths = (df_results.groupby("session")["duration"].sum() + pd.Series(index=range(1,1+num_sessions), data = 0)).fillna(0)
new_session_lengths

# %%
df.groupby("session")["duration"].sum().values

# %%
df.groupby("session")["duration"].sum().values - new_session_lengths
