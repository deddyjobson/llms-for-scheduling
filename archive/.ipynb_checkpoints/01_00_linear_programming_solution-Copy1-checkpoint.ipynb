# %%
from pulp import *
import numpy as np

# %%
import pandas as pd
import re
from bs4 import BeautifulSoup

# Without error capture to ensure the output (whether success or failure) is reported back.
# Attempt to read tables from the HTML file using pandas
file_path = "data/Program - MSR 2022.html"

# %%
with open(file_path, 'r') as file:
    html_content = file.read()

# %%
soup = BeautifulSoup(html_content, 'lxml')

# %%
rows = soup.find_all('tr', class_='hidable')

# %%
# Regex to match date pattern (e.g., "Tue 16 May")
date_pattern = re.compile(r"\b(?:Mon|Tue|Wed|Thu|Fri|Sat|Sun)\s\d{1,2}\s(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)")

# %%
extracted_rows = []

# Loop through each row to extract required details
for row in rows:
    temp_row = []
    
    # Extract session details from parent div if not already extracted
    session_div = row.find_previous('div', class_='session-info-in-table')
    session = session_div.get_text(strip=True) if session_div else ''
    
    datetime_info = row.find('td', class_='text-right')
    talk_info = row.find_all('td')[-1]
    
    if datetime_info and talk_info:
        time = datetime_info.find('div', class_='start-time').get_text(strip=True) if datetime_info.find('div', class_='start-time') else ''
        duration = datetime_info.find('strong').get_text(strip=True) if datetime_info.find('strong') else ''
        
        # Calculate end time based on start time and duration if needed
        
        temp_row.append(time)
        # temp_row.append(end_time)  # Calculate and append end time if needed
        temp_row.append(duration)
        
        talk_title = talk_info.find('strong')
        if talk_title:
            temp_row.append(talk_title.get_text(strip=True))
            
            link = talk_title.find('a', href=True)
            temp_row.append(link['href'] if link else '')
        else:
            temp_row.extend(['', ''])
            
        # Extract authors
        authors_div = talk_info.find('div', class_='performers')
        authors = [author.get_text(strip=True) for author in authors_div.find_all('a')] if authors_div else []
        temp_row.append(authors)
        
        # Append session information
        temp_row.append(session)
        
        # Locate date information
        # Tip: You may need to adjust how you locate the 'date information' based on your HTML structure
        date_info = row.find_previous('div', class_='day-wrapper')
        if date_info:
            date_text = date_info.get_text(strip=True)
            matched_date = date_pattern.search(date_text)
            date = matched_date.group(0) if matched_date else "Date Not Found"
        else:
            date = None
        temp_row.append(date)
        
        extracted_rows.append(temp_row)

columns = ['Time', 'Duration', 'Talk Title', 'Link', 'Authors', 'Session', 'Date']
df = pd.DataFrame(extracted_rows, columns=columns)

df.head()
# Out:
#     Time Duration                                         Talk Title Link  \
# 0  22:00       4m  An Empirical Evaluation of GitHub Copilot’s Co...    #
# 1  22:04       4m  Comments on Comments: Where Code Review and Do...    #
# 2  22:08       7m  Does This Apply to Me? An Empirical Study of T...    #
# 3  22:15       7m  Towards Reliable Agile Iterative Planning via ...    #
# 4  22:22       7m  BotHunter: An Approach to Detect Software Bots...    #
#
#                                              Authors  \
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...
#
#                                              Session        Date
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May

# %%
# Convert all column names to lowercase and replace spaces with hyphens
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# Put date first
df = df[['date'] + [col for col in df.columns if col != 'date']]

# Convert Time to start_time as datetime and calculate end_time
df['start_time'] = pd.to_datetime(df['date'] + ' ' + df['time'], format='%a %d %b %H:%M')
df['duration'] = df['duration'].str.extract('(\d+)').astype(int)  # Extract duration in minutes
df['end_time'] = df['start_time'] + pd.to_timedelta(df['duration'], unit='m')

# Delete the Link column
df = df.drop(['link', 'time'], axis=1)

# Move Authors column to the last position
df = df[[col for col in df.columns if col != 'authors'] + ['authors']]

df = df[['session', 'date', 'start_time', 'end_time', 'duration', 'talk_title','authors']]

# Display the final data frame
df.head()
# Out:
#                                              session        date  \
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
#
#            start_time            end_time  duration  \
# 0 1900-05-17 22:00:00 1900-05-17 22:04:00         4
# 1 1900-05-17 22:04:00 1900-05-17 22:08:00         4
# 2 1900-05-17 22:08:00 1900-05-17 22:15:00         7
# 3 1900-05-17 22:15:00 1900-05-17 22:22:00         7
# 4 1900-05-17 22:22:00 1900-05-17 22:29:00         7
#
#                                           talk_title  \
# 0  An Empirical Evaluation of GitHub Copilot’s Co...
# 1  Comments on Comments: Where Code Review and Do...
# 2  Does This Apply to Me? An Empirical Study of T...
# 3  Towards Reliable Agile Iterative Planning via ...
# 4  BotHunter: An Approach to Detect Software Bots...
#
#                                              authors
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...

# %%
df.dtypes
# Out:
# session               object
# date                  object
# start_time    datetime64[ns]
# end_time      datetime64[ns]
# duration               int64
# talk_title            object
# authors               object
# dtype: object

# %%
len(df)
# Out:
# 187

# %%
df["session"].unique()[:3]
# Out:
# array(['Session 1Technical Papers/Registered ReportsatMSR Main room - even hoursChair(s):Hongyu ZhangUniversity of Newcastle,Masud RahmanDalhousie University',
#        'Session 2: Maintenance (Issues & Smells)Technical Papers/Registered Reports/Data and Tool Showcase Track/Industry TrackatMSR Main room - odd hoursChair(s):Alessio FerrariCNR-ISTI',
#        'Session 3: Introspection, Vision, and Human AspectsTechnical Papers/Data and Tool Showcase Track/Industry Track/Registered ReportsatMSR Main room - odd hoursChair(s):Alexander SerebrenikEindhoven University of Technology,Sebastian BaltesSAP SE & University of Adelaide'],
#       dtype=object)

# %%
df[df["session"]=='Session 1Technical Papers/Registered ReportsatMSR Main room - even hoursChair(s):Hongyu ZhangUniversity of Newcastle,Masud RahmanDalhousie University']
# Out:
#                                              session        date  \
# 0  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 1  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 2  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 3  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 4  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 5  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
# 6  Session 1Technical Papers/Registered Reportsat...  Tue 17 May
#
#            start_time            end_time  duration  \
# 0 1900-05-17 22:00:00 1900-05-17 22:04:00         4
# 1 1900-05-17 22:04:00 1900-05-17 22:08:00         4
# 2 1900-05-17 22:08:00 1900-05-17 22:15:00         7
# 3 1900-05-17 22:15:00 1900-05-17 22:22:00         7
# 4 1900-05-17 22:22:00 1900-05-17 22:29:00         7
# 5 1900-05-17 22:29:00 1900-05-17 22:36:00         7
# 6 1900-05-17 22:36:00 1900-05-17 22:50:00        14
#
#                                           talk_title  \
# 0  An Empirical Evaluation of GitHub Copilot’s Co...
# 1  Comments on Comments: Where Code Review and Do...
# 2  Does This Apply to Me? An Empirical Study of T...
# 3  Towards Reliable Agile Iterative Planning via ...
# 4  BotHunter: An Approach to Detect Software Bots...
# 5  Recommending Code Improvements Based on Stack ...
# 6                                Discussions and Q&A
#
#                                              authors
# 0                          [Nhan Nguyen, Sarah Nadi]
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...
# 5         [Chaiyong Ragkhitwetsagul, Matheus Paixao]
# 6                                                 []

# %%
def merge_intervals(intervals):
    if not intervals:
        return 0
    
    # Sort intervals by the start time
    intervals.sort(key=lambda x: x[0])
    
    merged = [intervals[0]]
    for current_start, current_end in intervals[1:]:
        last_end = merged[-1][1]
        
        if current_start <= last_end:
            # There's an overlap, extend the previous interval
            merged[-1] = (merged[-1][0], max(last_end, current_end))
        else:
            # No overlap, add this interval as is
            merged.append((current_start, current_end))
    
    # Compute total duration in minutes (or another unit as desired)
    total_duration_minutes = sum((end - start).total_seconds() for start, end in merged) / 60  # convert seconds to minutes
    return total_duration_minutes

total_durations = []

for date, group in df.groupby('date'):
    intervals = list(zip(group['start_time'], group['end_time']))
    total_duration = merge_intervals(intervals)
    total_durations.append({'date': date, 'total_duration': total_duration})

# Converting the result into a DataFrame
total_duration_df = pd.DataFrame(total_durations)

total_duration_df
# Out:
#          date  total_duration
# 0  Fri 20 May           260.0
# 1  Mon 23 May           270.0
# 2  Thu 19 May           502.0
# 3  Tue 17 May            50.0
# 4  Tue 24 May           255.0
# 5  Wed 18 May           350.0

# %%
common_author_matrix = pd.DataFrame(np.zeros((len(df), len(df)), dtype=int), index=df['talk_title'], columns=df['talk_title'])

# Populate the matrix
for i in range(len(df)):
    for j in range(len(df)):
        # Intersect authors lists, if not empty set cell to 1
        if set(df.iloc[i]['authors']) & set(df.iloc[j]['authors']):
            common_author_matrix.iloc[i, j] = 1

common_author_matrix.head()
# Out:
# talk_title                                          An Empirical Evaluation of GitHub Copilot’s Code Suggestions  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  1
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  1
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Comments on Comments: Where Code Review and Documentation Meet  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  1
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Does This Apply to Me? An Empirical Study of Technical Context in Stack Overflow  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  1
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  1
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Towards Reliable Agile Iterative Planning via Predicting Documentation Changes of Work Items  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  1
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          BotHunter: An Approach to Detect Software Bots in GitHub  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  1
#
# talk_title                                          Recommending Code Improvements Based on Stack Overflow Answer Edits  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Discussions and Q&A  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                    0
# Comments on Comments: Where Code Review and Doc...                    0
# Does This Apply to Me? An Empirical Study of Te...                    0
# Towards Reliable Agile Iterative Planning via P...                    0
# BotHunter: An Approach to Detect Software Bots ...                    0
#
# talk_title                                          An Alternative Issue Tracking Dataset of Public Jira Repositories  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Smelly Variables in Ansible Infrastructure Code: Detection, Prevalence, and Lifetime  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Beyond Duplicates: Towards Understanding and Predicting Link Types in Issue Tracking Systems  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          ...  \
# talk_title                                          ...
# An Empirical Evaluation of GitHub Copilot’s Cod...  ...
# Comments on Comments: Where Code Review and Doc...  ...
# Does This Apply to Me? An Empirical Study of Te...  ...
# Towards Reliable Agile Iterative Planning via P...  ...
# BotHunter: An Approach to Detect Software Bots ...  ...
#
# talk_title                                          The General Index of Software Engineering Papers  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                 0
# Comments on Comments: Where Code Review and Doc...                                                 0
# Does This Apply to Me? An Empirical Study of Te...                                                 0
# Towards Reliable Agile Iterative Planning via P...                                                 0
# BotHunter: An Approach to Detect Software Bots ...                                                 0
#
# talk_title                                          Investigating the Impact of Forgetting in Software Development  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Discussions and Q&A  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                    0
# Comments on Comments: Where Code Review and Doc...                    0
# Does This Apply to Me? An Empirical Study of Te...                    0
# Towards Reliable Agile Iterative Planning via P...                    0
# BotHunter: An Approach to Detect Software Bots ...                    0
#
# talk_title                                          Code Review Practices for Refactoring Changes: An Empirical Study on OpenStack  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Painting the Landscape of Automotive Software in GitHub  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          SLNET: A Redistributable Corpus of 3rd-party Simulink Models  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          SoCCMiner: A Source Code-Comments and Comment-Context Miner  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          An Exploratory Study on Refactoring Documentation in Issues Handling  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Between JIRA and GitHub: ASFBot and its Influence on Human Comments in Issue Trackers  \
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                                                  0
# Comments on Comments: Where Code Review and Doc...                                                  0
# Does This Apply to Me? An Empirical Study of Te...                                                  0
# Towards Reliable Agile Iterative Planning via P...                                                  0
# BotHunter: An Approach to Detect Software Bots ...                                                  0
#
# talk_title                                          Discussions and Q&A
# talk_title
# An Empirical Evaluation of GitHub Copilot’s Cod...                    0
# Comments on Comments: Where Code Review and Doc...                    0
# Does This Apply to Me? An Empirical Study of Te...                    0
# Towards Reliable Agile Iterative Planning via P...                    0
# BotHunter: An Approach to Detect Software Bots ...                    0
#
# [5 rows x 187 columns]

# %% [markdown]
# ## Perform linear programming

# %%
papers = df[["talk_title","authors","duration"]]
papers.head()
# Out:
#                                           talk_title  \
# 0  An Empirical Evaluation of GitHub Copilot’s Co...
# 1  Comments on Comments: Where Code Review and Do...
# 2  Does This Apply to Me? An Empirical Study of T...
# 3  Towards Reliable Agile Iterative Planning via ...
# 4  BotHunter: An Approach to Detect Software Bots...
#
#                                              authors  duration
# 0                          [Nhan Nguyen, Sarah Nadi]         4
# 1  [Nikitha Rao, Jason Tsay, Martin Hirzel, Vince...         4
# 2  [Akalanka Galappaththi, Sarah Nadi, Christoph ...         7
# 3  [Jirat Pasuksmit, Patanamon Thongtanunam, Shan...         7
# 4  [Ahmad Abdellatif, Mairieli Wessel, Igor Stein...         7

# %%
df.dtypes
# Out:
# session               object
# date                  object
# start_time    datetime64[ns]
# end_time      datetime64[ns]
# duration               int64
# talk_title            object
# authors               object
# dtype: object

# %%
sessions = df.groupby("session")["duration"].sum()

sessions.head()
# Out:
# session
# Blended Technical Session 1 (Integration, Large-scale mining, and Software Ecosystems)Technical Papers/Data and Tool Showcase TrackatRoom 315+316Chair(s):Bogdan VasilescuCarnegie Mellon University, USA              90
# Blended Technical Session 2 (Machine Learning and Information Retrieval)Technical Papers/Data and Tool Showcase TrackatRoom 315+316Chair(s):Preetha ChatterjeeDrexel University, USA                                   90
# Blended Technical Session 3 (Smells and Maintenance)Technical Papers/Mining Challenge/Registered Reports/Data and Tool Showcase TrackatRoom 315+316Chair(s):Andy ZaidmanDelft University of Technology                 90
# Blended Technical Session 4 (Introspection, Vision, and Human Aspects)Technical Papers/Registered Reports/Data and Tool Showcase TrackatRoom 315+316Chair(s):Ayushi RastogiUniversity of Groningen, The Netherlands    75
# Blended Technical Session 5 (Miscellaneous)Technical Papers/Data and Tool Showcase Track/Mining ChallengeatRoom 315+316Chair(s):Luís CruzDeflt University of Technology                                                90
# Name: duration, dtype: int64

# %%
df.groupby("session").size().values
# Out:
# array([8, 7, 7, 6, 7, 1, 7, 3, 1, 8, 8, 7, 7, 7, 7, 9, 8, 7, 7, 7, 7, 8,
#        8, 8, 8, 7, 1, 1, 1, 1, 4, 4])

# %%
len(sessions)
# Out:
# 32

# %%
# Assumption of variables for illustration
num_sessions = len(sessions)  # Number of sessions as defined by PC chairs
session_lengths = sessions.values  # Length of each session in minutes
num_tracks = 2
# papers = [
#     {"title": "Paper1", "authors": ["Nhan Nguyen", "Sarah Nadi"], "duration": 20, "topics": ["GitHub", "Code Assistance"]},
#     {"title": "Paper2", "authors": ["Nikitha Rao"], "duration": 25, "topics": ["Code Review", "Documentation"]},
#     {"title": "Paper3", "authors": ["Akalanka Galappaththi"], "duration": 15, "topics": ["Empirical Study", "Type Systems"]},
#     # Add other papers similarly...
# ]

# %%
# Initiate the problem
prob = LpProblem("Conference_Schedule_Optimization", LpMinimize)

# Decision variables
schedule = LpVariable.dicts("schedule", ((i, j, k) for i in range(num_sessions) for j in range(len(papers)) for k in range(num_tracks)), cat='Binary')

# Objective function: For the basic structure, we make it a dummy one as our main focus is on satisfying constraints
prob += 0, "ArbitraryObjective"

# %%
# Constraints

# Ensure each paper is scheduled exactly once
for j in range(len(papers)):
    prob += lpSum(schedule[(i, j, k)] for i in range(num_sessions) for k in range(num_tracks)) == 1, f"One_placement_paper_{j}"

# Do not exceed session length
for i in range(num_sessions):
    for k in range(num_tracks):
        prob += lpSum(schedule[(i, j, k)] * papers.loc[j]["duration"] for j in range(len(papers))) <= session_lengths[i], f"Session_length_limit_{i}_{k}"

# No parallel scheduling of papers with common authors
# This part is tricky and depends on your exact requirement and how you've structured your data
# A simple and not very efficient way to approach it is to loop through every combination of papers and sessions
for i in range(num_sessions):
    for k1 in range(num_tracks):
        for k2 in range(k1+1, num_tracks):
            for j1, paper1 in papers.iterrows():
                for j2, paper2 in papers.iterrows():
                    if j1 != j2 and set(paper1["authors"]).intersection(paper2["authors"]):
                        prob += schedule[(i, j1, k1)] + schedule[(i, j2, k2)] <= 1, f"No_parallel_{j1}_{j2}_session_{i}"

# %%
# Solve the problem
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /var/tmp/1fdafd313b0941f0b4c47bc2917cd569-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/tmp/1fdafd313b0941f0b4c47bc2917cd569-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6848 COLUMNS
# At line 67906 RHS
# At line 74750 BOUNDS
# At line 86720 ENDATA
# Problem MODEL has 6843 rows, 11969 columns and 37120 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.02 seconds
# Cgl0005I 187 SOS with 11968 members
# Cgl0004I processed model has 6843 rows, 11968 columns (11968 integer (11968 of which binary)) and 37120 elements
# Cbc0038I Initial state - 30 integers unsatisfied sum - 6.22827
# Cbc0038I Pass   1: (0.25 seconds) suminf.    5.17524 (18) obj. 0 iterations 44
# Cbc0038I Pass   2: (0.25 seconds) suminf.    5.17524 (18) obj. 0 iterations 0
# Cbc0038I Pass   3: (0.26 seconds) suminf.    1.32000 (6) obj. 0 iterations 20
# Cbc0038I Pass   4: (0.27 seconds) suminf.    1.32000 (6) obj. 0 iterations 0
# Cbc0038I Pass   5: (0.27 seconds) suminf.    1.68000 (6) obj. 0 iterations 3
# Cbc0038I Pass   6: (0.28 seconds) suminf.    1.68000 (6) obj. 0 iterations 3
# Cbc0038I Pass   7: (0.29 seconds) suminf.    1.32000 (6) obj. 0 iterations 3
# Cbc0038I Pass   8: (0.30 seconds) suminf.    3.12952 (13) obj. 0 iterations 125
# Cbc0038I Pass   9: (0.31 seconds) suminf.    1.72000 (7) obj. 0 iterations 97
# Cbc0038I Pass  10: (0.32 seconds) suminf.    1.68000 (4) obj. 0 iterations 8
# Cbc0038I Pass  11: (0.32 seconds) suminf.    1.16000 (4) obj. 0 iterations 4
# Cbc0038I Pass  12: (0.33 seconds) suminf.    1.96000 (5) obj. 0 iterations 6
# Cbc0038I Pass  13: (0.34 seconds) suminf.    1.44000 (5) obj. 0 iterations 1
# Cbc0038I Pass  14: (0.35 seconds) suminf.    4.04238 (17) obj. 0 iterations 156
# Cbc0038I Pass  15: (0.36 seconds) suminf.    2.59619 (12) obj. 0 iterations 115
# Cbc0038I Pass  16: (0.37 seconds) suminf.    0.77143 (4) obj. 0 iterations 32
# Cbc0038I Pass  17: (0.38 seconds) suminf.    0.44000 (2) obj. 0 iterations 7
# Cbc0038I Pass  18: (0.38 seconds) suminf.    0.60000 (2) obj. 0 iterations 3
# Cbc0038I Pass  19: (0.39 seconds) suminf.    1.64000 (7) obj. 0 iterations 145
# Cbc0038I Pass  20: (0.40 seconds) suminf.    1.64000 (6) obj. 0 iterations 122
# Cbc0038I Pass  21: (0.41 seconds) suminf.    1.84000 (4) obj. 0 iterations 20
# Cbc0038I Pass  22: (0.42 seconds) suminf.    1.32000 (4) obj. 0 iterations 2
# Cbc0038I Pass  23: (0.43 seconds) suminf.    1.12000 (4) obj. 0 iterations 9
# Cbc0038I Pass  24: (0.43 seconds) suminf.    0.60000 (4) obj. 0 iterations 2
# Cbc0038I Pass  25: (0.44 seconds) suminf.    2.09143 (8) obj. 0 iterations 153
# Cbc0038I Pass  26: (0.45 seconds) suminf.    1.78667 (9) obj. 0 iterations 129
# Cbc0038I Pass  27: (0.46 seconds) suminf.    1.16000 (5) obj. 0 iterations 29
# Cbc0038I Pass  28: (0.46 seconds) suminf.    1.16000 (5) obj. 0 iterations 0
# Cbc0038I Pass  29: (0.47 seconds) suminf.    0.96000 (5) obj. 0 iterations 12
# Cbc0038I Pass  30: (0.48 seconds) suminf.    0.60000 (5) obj. 0 iterations 2
# Cbc0038I Pass  31: (0.49 seconds) suminf.    1.52000 (5) obj. 0 iterations 12
# Cbc0038I Pass  32: (0.50 seconds) suminf.    2.75429 (14) obj. 0 iterations 178
# Cbc0038I Pass  33: (0.51 seconds) suminf.    1.71429 (11) obj. 0 iterations 173
# Cbc0038I Pass  34: (0.52 seconds) suminf.    1.40000 (8) obj. 0 iterations 37
# Cbc0038I Pass  35: (0.52 seconds) suminf.    1.40000 (8) obj. 0 iterations 0
# Cbc0038I Pass  36: (0.53 seconds) suminf.    0.88000 (8) obj. 0 iterations 19
# Cbc0038I Pass  37: (0.54 seconds) suminf.    0.88000 (6) obj. 0 iterations 4
# Cbc0038I Pass  38: (0.55 seconds) suminf.    2.69333 (10) obj. 0 iterations 213
# Cbc0038I Pass  39: (0.56 seconds) suminf.    1.44000 (9) obj. 0 iterations 186
# Cbc0038I Pass  40: (0.57 seconds) suminf.    2.28000 (9) obj. 0 iterations 42
# Cbc0038I Pass  41: (0.57 seconds) suminf.    1.64000 (6) obj. 0 iterations 5
# Cbc0038I Pass  42: (0.58 seconds) suminf.    0.84000 (5) obj. 0 iterations 19
# Cbc0038I Pass  43: (0.59 seconds) suminf.    0.80000 (5) obj. 0 iterations 5
# Cbc0038I Pass  44: (0.60 seconds) suminf.    1.08000 (5) obj. 0 iterations 14
# Cbc0038I Pass  45: (0.61 seconds) suminf.    1.04000 (4) obj. 0 iterations 7
# Cbc0038I Pass  46: (0.62 seconds) suminf.    2.91524 (13) obj. 0 iterations 171
# Cbc0038I Pass  47: (0.63 seconds) suminf.    2.31524 (12) obj. 0 iterations 146
# Cbc0038I Pass  48: (0.63 seconds) suminf.    1.60000 (6) obj. 0 iterations 38
# Cbc0038I Pass  49: (0.64 seconds) suminf.    1.44000 (6) obj. 0 iterations 9
# Cbc0038I Pass  50: (0.65 seconds) suminf.    2.12000 (6) obj. 0 iterations 18
# Cbc0038I Pass  51: (0.66 seconds) suminf.    1.44000 (6) obj. 0 iterations 15
# Cbc0038I Pass  52: (0.67 seconds) suminf.    2.12000 (6) obj. 0 iterations 20
# Cbc0038I Pass  53: (0.68 seconds) suminf.    2.50000 (8) obj. 0 iterations 162
# Cbc0038I Pass  54: (0.69 seconds) suminf.    1.04000 (4) obj. 0 iterations 157
# Cbc0038I Pass  55: (0.70 seconds) suminf.    1.72000 (4) obj. 0 iterations 13
# Cbc0038I Pass  56: (0.70 seconds) suminf.    0.64000 (2) obj. 0 iterations 5
# Cbc0038I Pass  57: (0.71 seconds) suminf.    0.92000 (2) obj. 0 iterations 4
# Cbc0038I Pass  58: (0.72 seconds) suminf.    3.25048 (12) obj. 0 iterations 155
# Cbc0038I Pass  59: (0.73 seconds) suminf.    1.57947 (10) obj. 0 iterations 157
# Cbc0038I Pass  60: (0.74 seconds) suminf.    1.05818 (4) obj. 0 iterations 29
# Cbc0038I Pass  61: (0.75 seconds) suminf.    0.24000 (2) obj. 0 iterations 6
# Cbc0038I Pass  62: (0.76 seconds) suminf.    0.64000 (2) obj. 0 iterations 3
# Cbc0038I Pass  63: (0.77 seconds) suminf.    2.76964 (15) obj. 0 iterations 178
# Cbc0038I Pass  64: (0.78 seconds) suminf.    2.20571 (12) obj. 0 iterations 163
# Cbc0038I Pass  65: (0.79 seconds) suminf.    2.80000 (10) obj. 0 iterations 38
# Cbc0038I Pass  66: (0.80 seconds) suminf.    2.00000 (8) obj. 0 iterations 10
# Cbc0038I Pass  67: (0.81 seconds) suminf.    3.04000 (8) obj. 0 iterations 30
# Cbc0038I Pass  68: (0.82 seconds) suminf.    2.36000 (8) obj. 0 iterations 17
# Cbc0038I Pass  69: (0.82 seconds) suminf.    2.68000 (8) obj. 0 iterations 27
# Cbc0038I Pass  70: (0.83 seconds) suminf.    3.70571 (12) obj. 0 iterations 172
# Cbc0038I Pass  71: (0.85 seconds) suminf.    2.40571 (9) obj. 0 iterations 166
# Cbc0038I Pass  72: (0.85 seconds) suminf.    2.40571 (9) obj. 0 iterations 0
# Cbc0038I Pass  73: (0.86 seconds) suminf.    2.12000 (6) obj. 0 iterations 31
# Cbc0038I Pass  74: (0.87 seconds) suminf.    2.00000 (6) obj. 0 iterations 6
# Cbc0038I Pass  75: (0.87 seconds) suminf.    1.72000 (6) obj. 0 iterations 22
# Cbc0038I Pass  76: (0.88 seconds) suminf.    1.60000 (6) obj. 0 iterations 6
# Cbc0038I Pass  77: (0.89 seconds) suminf.    2.12000 (6) obj. 0 iterations 20
# Cbc0038I Pass  78: (0.90 seconds) suminf.    3.51496 (10) obj. 0 iterations 168
# Cbc0038I Pass  79: (0.91 seconds) suminf.    2.45143 (9) obj. 0 iterations 157
# Cbc0038I Pass  80: (0.92 seconds) suminf.    0.60000 (2) obj. 0 iterations 16
# Cbc0038I Pass  81: (0.92 seconds) suminf.    0.60000 (2) obj. 0 iterations 0
# Cbc0038I Pass  82: (0.93 seconds) suminf.    0.72000 (2) obj. 0 iterations 10
# Cbc0038I Pass  83: (0.94 seconds) suminf.    1.28000 (6) obj. 0 iterations 185
# Cbc0038I Pass  84: (0.95 seconds) suminf.    1.28000 (6) obj. 0 iterations 146
# Cbc0038I Pass  85: (0.96 seconds) suminf.    2.04000 (6) obj. 0 iterations 25
# Cbc0038I Pass  86: (0.97 seconds) suminf.    1.60000 (6) obj. 0 iterations 5
# Cbc0038I Pass  87: (0.98 seconds) suminf.    2.24000 (7) obj. 0 iterations 15
# Cbc0038I Pass  88: (0.99 seconds) suminf.    1.88000 (7) obj. 0 iterations 3
# Cbc0038I Pass  89: (0.99 seconds) suminf.    1.96000 (6) obj. 0 iterations 11
# Cbc0038I Pass  90: (1.00 seconds) suminf.    5.00286 (15) obj. 0 iterations 177
# Cbc0038I Pass  91: (1.01 seconds) suminf.    3.52857 (11) obj. 0 iterations 175
# Cbc0038I Pass  92: (1.02 seconds) suminf.    1.60000 (4) obj. 0 iterations 35
# Cbc0038I Pass  93: (1.03 seconds) suminf.    1.08000 (4) obj. 0 iterations 2
# Cbc0038I Pass  94: (1.04 seconds) suminf.    0.80000 (2) obj. 0 iterations 6
# Cbc0038I Pass  95: (1.05 seconds) suminf.    0.28000 (2) obj. 0 iterations 2
# Cbc0038I Pass  96: (1.06 seconds) suminf.    2.38714 (8) obj. 0 iterations 158
# Cbc0038I Pass  97: (1.07 seconds) suminf.    1.65099 (7) obj. 0 iterations 148
# Cbc0038I Pass  98: (1.07 seconds) suminf.    1.15619 (5) obj. 0 iterations 24
# Cbc0038I Pass  99: (1.08 seconds) suminf.    1.15619 (5) obj. 0 iterations 0
# Cbc0038I Pass 100: (1.09 seconds) suminf.    1.92769 (10) obj. 0 iterations 156
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 11150 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 6843 rows 11968 columns, reduced to 233 rows 777 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to 0 (1.15 seconds)
# Cbc0038I After 1.15 seconds - Feasibility pump exiting with objective of 0 - took 0.92 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (1.15 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (1.16 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.15
# Time (Wallclock seconds):       1.18
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.19   (Wallclock seconds):       1.22
# 1

# %%
# Output schedule (simple print, you'd need to format it more nicely)
for i in range(num_sessions):
    for k in range(num_tracks):
        print(f"Session {i+1}, Track {k+1}")
        for j in range(len(papers)):
            if schedule[(i, j, k)].varValue == 1:
                print(f"  Paper: {papers.loc[j]['talk_title']} | Duration: {papers.loc[j]['duration']} mins")
        print("\n")
# Out:
# Session 1, Track 1
#   Paper: Discussions and Q&A | Duration: 14 mins
#   Paper: An Empirical Study on Maintainable Method Size in Java | Duration: 7 mins
#   Paper: How heated is it? Understanding GitHub locked issues | Duration: 7 mins
#   Paper: The OCEAN mailing list data set: Network analysis spanning mailing lists and code repositories | Duration: 4 mins
#   Paper: WeakSATD: detecting weak self-admitted technical debt | Duration: 4 mins
#   Paper: A Time Series-Based Dataset of Open-Source Software Evolution | Duration: 4 mins
#   Paper: Finding the Fun in Fundraising: Public Issues and Pull Requests in VC-backed Open-Core Companies | Duration: 7 mins
#   Paper: Discussions and Q&A | Duration: 20 mins
#   Paper: Code Review Practices for Refactoring Changes: An Empirical Study on OpenStack | Duration: 15 mins
#
#
# Session 1, Track 2
#   Paper: SECOM: Towards a convention for security commit messagesFOSS Impact Paper Award | Duration: 7 mins
#
#
# Session 2, Track 1
#   Paper: Between JIRA and GitHub: ASFBot and its Influence on Human Comments in Issue Trackers | Duration: 4 mins
#   Paper: SLNET: A Redistributable Corpus of 3rd-party Simulink Models | Duration: 4 mins
#   Paper: TwinDroid: A Dataset of Android app System call traces and Trace Generation Pipeline | Duration: 4 mins
#   Paper: Evaluating few shot and Contrastive learning Methods for Code Clone Detection | Duration: 4 mins
#   Paper: Bot Detection in GitHub Repositories | Duration: 5 mins
#   Paper: Varangian: A Git Bot for Augmented Static Analysis | Duration: 7 mins
#   Paper: The Unexplored Treasure Trove of Phabricator Code Reviews | Duration: 8 mins
#   Paper: Discussions and Q&A | Duration: 21 mins
#   Paper: Between JIRA and GitHub: ASFBot and its Influence on Human Comments in Issue Trackers | Duration: 8 mins
#
#
# Session 2, Track 2
#   Paper: Discussions and Q&A | Duration: 17 mins
#   Paper: Discussions and Q&A | Duration: 13 mins
#   Paper: On the Use of Fine-grained Vulnerable Code Statements for Software Vulnerability Assessment Models | Duration: 7 mins
#   Paper: Using Datalore for Reproducible Research | Duration: 50 mins
#
#
# Session 3, Track 1
#   Paper: Lupa: A Platform for Large Scale Analysis of The Progamming Language Usage | Duration: 4 mins
#   Paper: Evaluating the effectiveness of local explanation methods on source code-based defect prediction models | Duration: 4 mins
#   Paper: Using Bandit Algorithms for Selecting Feature Reduction Techniques in Software Defect Prediction | Duration: 7 mins
#   Paper: Is GitHub's Copilot as Bad As Humans at Introducing Vulnerabilities in Code? | Duration: 4 mins
#   Paper: LAGOON: An Analysis Tool for Open Source Communities | Duration: 8 mins
#   Paper: Beyond Duplicates: Towards Understanding and Predicting Link Types in Issue Tracking Systems | Duration: 15 mins
#
#
# Session 3, Track 2
#   Paper: Replicating Data Pipelines with GrimoireLab | Duration: 5 mins
#
#
# Session 4, Track 1
#   Paper: Inspect4py: A Knowledge Extraction Framework for Python Code Repositories | Duration: 4 mins
#   Paper: Methods2Test: A dataset of focal methods mapped to test cases | Duration: 4 mins
#   Paper: Discussions and Q&A | Duration: 16 mins
#   Paper: The Next Generation of Software Developers | Duration: 10 mins
#
#
# Session 4, Track 2
#   Paper: Recommending Code Improvements Based on Stack Overflow Answer Edits | Duration: 7 mins
#
#
# Session 5, Track 1
#   Paper: Mining the Ethereum Blockchain Platform: Best Practices and Pitfalls | Duration: 50 mins
#   Paper: Does Configuration Encoding Matter in Learning Software Performance? An Empirical Study on Encoding Schemes | Duration: 7 mins
#   Paper: Do Small Code Changes Merge Faster? A Multi-Language Empirical Investigation | Duration: 7 mins
#   Paper: GraphCode2Vec: Generic Code Embedding via Lexical and Program Dependence Analyses | Duration: 15 mins
#
#
# Session 5, Track 2
#
#
# Session 6, Track 1
#   Paper: Is Refactoring Always a Good Egg? Exploring the Interconnection Between Bugs and Refactorings | Duration: 4 mins
#   Paper: Do Customized Android Frameworks Keep Pace with Android? | Duration: 7 mins
#   Paper: Discussions and Q&A | Duration: 14 mins
#   Paper: The General Index of Software Engineering Papers | Duration: 8 mins
#
#
# Session 6, Track 2
#   Paper: To What Extent do Deep Learning-based Code Recommenders Generate Predictions by Cloning Code from the Training Set? | Duration: 7 mins
#   Paper: Investigating the Impact of Forgetting in Software Development | Duration: 8 mins
#
#
# Session 7, Track 1
#   Paper: Which bugs are missed in code reviews: An empirical study on SmartSHARK dataset | Duration: 4 mins
#   Paper: Characterizing High-Quality Test Methods: A First Empirical Study | Duration: 4 mins
#   Paper: Constructing Dataset of Functionally Equivalent Java Methods Using Automated Test Generation Techniques | Duration: 4 mins
#   Paper: A Large-scale Dataset of (Open Source) License Text VariantsData and Tool Showcase Award | Duration: 4 mins
#   Paper: TSSB-3M: Mining single statement bugs at massive scale | Duration: 8 mins
#   Paper: Discussions and Q&A | Duration: 21 mins
#
#
# Session 7, Track 2
#   Paper: Quid Pro Quo: An Exploration of Reciprocity in Code Review | Duration: 5 mins
#
#
# Session 8, Track 1
#   Paper: An Alternative Issue Tracking Dataset of Public Jira Repositories | Duration: 4 mins
#   Paper: Complex Python Features in the Wild | Duration: 7 mins
#   Paper: Dataset: Dependency Networks of Open Source Libraries Available Through CocoaPods, Carthage and Swift PM | Duration: 4 mins
#   Paper: Mining Software Repositories in the age of AI | Duration: 10 mins
#   Paper: ECench: An Energy Bug Benchmark of Ethereum Client Software | Duration: 4 mins
#   Paper: Problems and Solutions in Applying Continuous Integration and Delivery to 20 Open-Source Cyber-Physical Systems | Duration: 7 mins
#   Paper: Dataset: Dependency Networks of Open Source Libraries Available Through CocoaPods, Carthage and Swift PM | Duration: 8 mins
#   Paper: Operationalizing Threats to MSR Studies by Simulation-Based TestingDistinguished Paper Award | Duration: 15 mins
#
#
# Session 8, Track 2
#
#
# Session 9, Track 1
#   Paper: Exploring Apache Incubator Project Trajectories with APEX | Duration: 4 mins
#   Paper: On the Naturalness of Fuzzer Generated Code | Duration: 4 mins
#   Paper: Multimodal Recommendation of Messenger Channels | Duration: 7 mins
#   Paper: FaST: A linear time stack trace alignment heuristic for crash report deduplication | Duration: 7 mins
#   Paper: GrimoireLab Maintenance and Evolution | Duration: 5 mins
#   Paper: Challenges in Migrating Imperative Deep Learning Programs to Graph Execution: An Empirical Study | Duration: 15 mins
#
#
# Session 9, Track 2
#   Paper: Refactoring Debt: Myth or Reality? An Exploratory Study on the Relationship Between Technical Debt and RefactoringBest Mining Challenge Paper Award | Duration: 4 mins
#
#
# Session 10, Track 1
#   Paper: Does This Apply to Me? An Empirical Study of Technical Context in Stack Overflow | Duration: 7 mins
#   Paper: Operationalizing Threats to MSR Studies by Simulation-Based TestingDistinguished Paper Award | Duration: 7 mins
#   Paper: LineVul: A Transformer-based Line-Level Vulnerability Prediction | Duration: 7 mins
#   Paper: A Versatile Dataset of Agile Open Source Software Projects | Duration: 4 mins
#   Paper: GitRank: A Framework to Rank GitHub Repositories | Duration: 5 mins
#
#
# Session 10, Track 2
#
#
# Session 11, Track 1
#   Paper: Beyond Duplicates: Towards Understanding and Predicting Link Types in Issue Tracking Systems | Duration: 7 mins
#   Paper: Dazzle: Using Optimized Generative Adversarial Networks to Address Security Data Class Imbalance Issue | Duration: 7 mins
#   Paper: The Unexplored Treasure Trove of Phabricator Code Reviews | Duration: 4 mins
#
#
# Session 11, Track 2
#   Paper: MSR Foundational Contribution Award | Duration: 50 mins
#
#
# Session 12, Track 1
#   Paper: Challenges and Future Research Direction for Microtask Programming in Industry | Duration: 7 mins
#   Paper: Mining the Usage of Reactive Programming APIs: A Study on GitHub and Stack Overflow | Duration: 7 mins
#   Paper: A Large-Scale Comparison of Python Code in Jupyter Notebooks and ScriptsDistinguished Paper Award | Duration: 7 mins
#   Paper: Challenges in Migrating Imperative Deep Learning Programs to Graph Execution: An Empirical Study | Duration: 7 mins
#   Paper: Discussions and Q&A | Duration: 14 mins
#   Paper: An Exploratory Study on Refactoring Documentation in Issues Handling | Duration: 8 mins
#
#
# Session 12, Track 2
#   Paper: Tooling for Time- and Space-efficient git Repository Mining | Duration: 4 mins
#
#
# Session 13, Track 1
#   Paper: Towards Using Gameplay Videos for Detecting Issues in Video Games | Duration: 4 mins
#   Paper: Is Surprisal in Issue Trackers Actionable? | Duration: 4 mins
#   Paper: MIP Award Talk | Duration: 35 mins
#
#
# Session 13, Track 2
#
#
# Session 14, Track 1
#   Paper: Studying the Impact of Continuous Delivery Adoption on Bug-Fixing Time in Apache’s Open-Source Projects | Duration: 4 mins
#   Paper: TSSB-3M: Mining single statement bugs at massive scale | Duration: 4 mins
#   Paper: Discussions and Q&A | Duration: 14 mins
#   Paper: Methods for Stabilizing Models across Large Samples of Projects(with case studies on Predicting Defect and Project Health) | Duration: 15 mins
#
#
# Session 14, Track 2
#   Paper: Mining Code Review Data to Understand Waiting Times Between Acceptance and Merging: An Empirical Analysis | Duration: 7 mins
#
#
# Session 15, Track 1
#   Paper: npm-filter: Automating the mining of dynamic information from npm packages | Duration: 4 mins
#   Paper: A Culture of Productivity: Maximizing Productivity by Maximizing Wellbeing | Duration: 7 mins
#   Paper: Discussions and Q&A | Duration: 13 mins
#   Paper: Discussions and Q&A | Duration: 21 mins
#
#
# Session 15, Track 2
#   Paper: Empirical Standards for Repository Mining | Duration: 50 mins
#
#
# Session 16, Track 1
#   Paper: Discussions and Q&A | Duration: 16 mins
#   Paper: Senatus: A Fast and Accurate Code-to-Code Recommendation Engine | Duration: 15 mins
#   Paper: On the Naturalness of Fuzzer Generated Code | Duration: 8 mins
#
#
# Session 16, Track 2
#   Paper: How to Improve Deep Learning for Software Analytics (a case study with code smell detection) | Duration: 15 mins
#
#
# Session 17, Track 1
#   Paper: ApacheJIT: A Large Dataset for Just-In-Time Defect Prediction | Duration: 4 mins
#   Paper: Improved Business Outcomes from Cloud Applications – using Integrated Process and Runtime Product Data Mining | Duration: 7 mins
#   Paper: Discussions and Q&A | Duration: 11 mins
#   Paper: Can instability variations warn developers when open-source projects boost? | Duration: 4 mins
#   Paper: Discussions and Q&A | Duration: 20 mins
#
#
# Session 17, Track 2
#   Paper: Code Review Practices for Refactoring Changes: An Empirical Study on OpenStack | Duration: 7 mins
#
#
# Session 18, Track 1
#   Paper: Discussions and Q&A | Duration: 17 mins
#   Paper: Discussions and Q&A | Duration: 20 mins
#   Paper: Back to the future: Empirical Revolution(s) in Software Engineering | Duration: 10 mins
#
#
# Session 18, Track 2
#
#
# Session 19, Track 1
#   Paper: AndroOBFS: Time-tagged Obfuscated Android Malware Dataset with Family Information | Duration: 4 mins
#   Paper: It's all in your network: How mining developer collaboration allowed us to peer into complex socio-technical aspects of software development | Duration: 10 mins
#   Paper: Discussions and Q&A | Duration: 12 mins
#   Paper: Do Small Code Changes Merge Faster? A Multi-Language Empirical Investigation | Duration: 15 mins
#   Paper: A Large-scale Dataset of (Open Source) License Text VariantsData and Tool Showcase Award | Duration: 8 mins
#
#
# Session 19, Track 2
#
#
# Session 20, Track 1
#   Paper: Geographic Diversity in Public Code Contributions | Duration: 4 mins
#   Paper: Painting the Landscape of Automotive Software in GitHub | Duration: 7 mins
#   Paper: LineVD: Statement-level Vulnerability Detection using Graph Neural Networks | Duration: 7 mins
#   Paper: FixJS: A Dataset of Bug-fixing JavaScript Commits | Duration: 4 mins
#   Paper: Discussions and Q&A | Duration: 28 mins
#
#
# Session 20, Track 2
#
#
# Session 21, Track 1
#   Paper: An Empirical Evaluation of GitHub Copilot’s Code Suggestions | Duration: 4 mins
#   Paper: Discussions and Q&A | Duration: 13 mins
#   Paper: SniP: An Efficient Stack Tracing Framework for Multi-threaded Programs | Duration: 4 mins
#   Paper: Engineering the MSR Field and the Joy of Research | Duration: 10 mins
#   Paper: Towards Understanding Barriers and Mitigation Strategies of Software Engineers with Non-traditional Educational and Occupational Backgrounds | Duration: 4 mins
#   Paper: Detecting Privacy-Sensitive Code Changes with Language Modeling | Duration: 7 mins
#   Paper: Comments on Comments: Where Code Review and Documentation Meet | Duration: 8 mins
#
#
# Session 21, Track 2
#   Paper: Software Bots in Software Engineering: Benefits and Challenges | Duration: 50 mins
#
#
# Session 22, Track 1
#   Paper: Starting the InnerSource Journey: Key Goals and Metrics to Measure Collaboration | Duration: 7 mins
#   Paper: ManyTypes4TypeScript: A Comprehensive TypeScript Dataset for Sequence-Based Type Inference | Duration: 4 mins
#   Paper: An Empirical Study on the Survival Rate of GitHub Projects | Duration: 7 mins
#   Paper: Improve Quality of Cloud Serverless Architectures through Software Repository Mining | Duration: 7 mins
#   Paper: SOSum: A Dataset of Stack Overflow Post Summaries | Duration: 8 mins
#   Paper: npm-filter: Automating the mining of dynamic information from npm packages | Duration: 8 mins
#
#
# Session 22, Track 2
#   Paper: CamBench - Cryptographic API Misuse Detection Tool Benchmark Suite | Duration: 8 mins
#
#
# Session 23, Track 1
#   Paper: On the Co-Occurrence of Refactoring of Test and Source Code | Duration: 4 mins
#   Paper: Methods for Stabilizing Models across Large Samples of Projects(with case studies on Predicting Defect and Project Health) | Duration: 7 mins
#
#
# Session 23, Track 2
#   Paper: From Models to Systems: Rethinking the Role of Software Engineering for Machine Learning | Duration: 35 mins
#
#
# Session 24, Track 1
#   Paper: CLIP meets GamePhysics: Towards bug identification in gameplay videos using zero-shot transfer learning | Duration: 7 mins
#   Paper: On the Violation of Honesty in Mobile Apps: Automated Detection and CategoriesDistinguished Paper Award | Duration: 7 mins
#   Paper: The Unsolvable Problem or the Unheard Answer? A Dataset of 24,669 Open-Source Software Conference Talks | Duration: 4 mins
#   Paper: LibDB: An Effective and Efficient Framework for Detecting Third-Party Libraries in Binaries | Duration: 7 mins
#   Paper: Mining Code Review Data to Understand Waiting Times Between Acceptance and Merging: An Empirical Analysis | Duration: 15 mins
#
#
# Session 24, Track 2
#
#
# Session 25, Track 1
#   Paper: MIP Award Talk | Duration: 50 mins
#
#
# Session 25, Track 2
#   Paper: BotHunter: An Approach to Detect Software Bots in GitHub | Duration: 7 mins
#
#
# Session 26, Track 1
#   Paper: Using Active Learning to Find High-Fidelity Builds | Duration: 7 mins
#   Paper: Vul4J: A Dataset of Reproducible Java Vulnerabilities Geared Towards the Study of Program Repair TechniquesData and Tool Showcase Award | Duration: 4 mins
#   Paper: Bias in MSR research | Duration: 10 mins
#   Paper: Microsoft CloudMine: Data Mining for the Executive Order on Improving the Nation’s Cybersecurity | Duration: 7 mins
#   Paper: LAGOON: An Analysis Tool for Open Source Communities | Duration: 4 mins
#
#
# Session 26, Track 2
#   Paper: Smelly Variables in Ansible Infrastructure Code: Detection, Prevalence, and Lifetime | Duration: 15 mins
#
#
# Session 27, Track 1
#   Paper: The General Index of Software Engineering Papers | Duration: 4 mins
#   Paper: GitDelver Enterprise Dataset (GDED): An Industrial Closed-source Dataset for Socio-Technical Research | Duration: 4 mins
#   Paper: Noisy Label Learning for Security Defects | Duration: 7 mins
#   Paper: To Type or Not to Type? A Systematic Comparison of the Software Quality of JavaScript and TypeScript Applications on GitHub | Duration: 7 mins
#   Paper: Automatically Prioritizing and Assigning Tasks from Code Repositories in Puzzle Driven Development | Duration: 7 mins
#   Paper: Painting the Landscape of Automotive Software in GitHub | Duration: 15 mins
#
#
# Session 27, Track 2
#   Paper: Smelly Variables in Ansible Infrastructure Code: Detection, Prevalence, and Lifetime | Duration: 7 mins
#   Paper: How to Improve Deep Learning for Software Analytics (a case study with code smell detection) | Duration: 7 mins
#   Paper: In-Person MSR 2022 Opening Session | Duration: 20 mins
#
#
# Session 28, Track 1
#   Paper: Comments on Comments: Where Code Review and Documentation Meet | Duration: 4 mins
#   Paper: SoCCMiner: A Source Code-Comments and Comment-Context Miner | Duration: 4 mins
#   Paper: Toward Granular Automatic Unit Test Case Generation | Duration: 4 mins
#   Paper: CamBench - Cryptographic API Misuse Detection Tool Benchmark Suite | Duration: 4 mins
#   Paper: Discussion | Duration: 21 mins
#   Paper: OpenSSL 3.0.0: An exploratory case study | Duration: 5 mins
#   Paper: SLNET: A Redistributable Corpus of 3rd-party Simulink Models | Duration: 8 mins
#
#
# Session 28, Track 2
#   Paper: DISCO: A Dataset of Discord Chat Conversations for Software Engineering Research | Duration: 4 mins
#
#
# Session 29, Track 1
#   Paper: Real-World Clone-Detection in Go | Duration: 7 mins
#   Paper: TriggerZoo: A Dataset of Android Applications Automatically Infected with Logic Bombs | Duration: 4 mins
#   Paper: Extracting corrective actions from code repositories | Duration: 7 mins
#   Paper: Discussions and Q&A | Duration: 17 mins
#
#
# Session 29, Track 2
#
#
# Session 30, Track 1
#   Paper: Towards Reliable Agile Iterative Planning via Predicting Documentation Changes of Work Items | Duration: 7 mins
#   Paper: DaSEA – A Dataset for Software Ecosystem Analysis | Duration: 4 mins
#   Paper: Is Open Source Eating the World’s Software? Measuring the Proportion of Open Source in proprietary software using Java Binaries | Duration: 4 mins
#   Paper: Geographic Diversity in Public Code Contributions | Duration: 8 mins
#
#
# Session 30, Track 2
#   Paper: Discussions and Q&A | Duration: 22 mins
#
#
# Session 31, Track 1
#   Paper: An Exploratory Study on Refactoring Documentation in Issues Handling | Duration: 4 mins
#   Paper: SOSum: A Dataset of Stack Overflow Post Summaries | Duration: 4 mins
#   Paper: Senatus: A Fast and Accurate Code-to-Code Recommendation Engine | Duration: 7 mins
#   Paper: GraphCode2Vec: Generic Code Embedding via Lexical and Program Dependence Analyses | Duration: 7 mins
#   Paper: A Deep Study of the Effects and Fixes of Server-Side Request Races in Web Applications | Duration: 7 mins
#   Paper: Refactoring Debt: Myth or Reality? An Exploratory Study on the Relationship Between Technical Debt and RefactoringBest Mining Challenge Paper Award | Duration: 8 mins
#   Paper: SoCCMiner: A Source Code-Comments and Comment-Context Miner | Duration: 8 mins
#
#
# Session 31, Track 2
#
#
# Session 32, Track 1
#   Paper: Investigating the Impact of Forgetting in Software Development | Duration: 4 mins
#   Paper: ReCover: a Curated Dataset for Regression Testing Research | Duration: 4 mins
#   Paper: Discussion | Duration: 21 mins
#
#
# Session 32, Track 2
#   Paper: Discussions and Q&A | Duration: 14 mins
